# %% [markdown]
# # **Attention Ensemble  - Soft Voting**
# ---

# %% [markdown]
# ### **Import Libraries**

# %%
import tensorflow as tf
from keras.models import Model
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split 

import unicodedata
import re
import numpy as np
import os
import io
import time
import random
import openpyxl

# %% [markdown]
# ### **데이터 로드**

# %%
path_to_file = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/spa-eng/spa.txt'
path_to_file_esb = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/spa-eng/spa_for_esb.txt'

# %% [markdown]
# ### **데이터 랜덤 셔플**
#
#
# *   [영어, 스페인어] 쌍 shuffle file 새로 저장
# *   번역 테스트 시 주석 처리

# %%
# lines = io.open(path_to_file, encoding='UTF-8').read().strip().split('\n')
# random.shuffle(lines)
# f = open(path_to_file_esb, 'w')
# for i in lines:
#     data = i + '\n'
#     f.write(data)
# f.close()

# %% [markdown]
# ### **데이터(문장) 전처리**

# %%
# 유니코드 파일을 아스키 코드 파일로 변환합니다.
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # 단어와 단어 뒤에 오는 구두점(.)사이에 공백을 생성합니다.
  # 예시: "he is a boy." => "he is a boy ."
  # 참고:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # (a-z, A-Z, ".", "?", "!", ",")을 제외한 모든 것을 공백으로 대체합니다.
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # 모델이 예측을 시작하거나 중단할 때를 알게 하기 위해서
  # 문장에 start와 end 토큰을 추가합니다.
  w = '<start> ' + w + ' <end>'
  return w

# %% [markdown]
# ### **Dataset 생성**
# 1. 문장에 있는 억양을 제거합니다.
# 2. 불필요한 문자를 제거하여 문장을 정리합니다.
# 3. 다음과 같은 형식으로 문장의 쌍을 반환합니다: [영어, 스페인어]

# %%
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %% [markdown]
# ### **Language 가 들어오면 공백 단위로 토큰화**
# - fit_on_texts(): 문자 데이터를 입력받아서 리스트의 형태로 변환
# - texts_to_sequences: 텍스트 안의 단어들을 숫자 시퀀스로 출력
# - pad_sequcences(tensor, padding='post') : 서로 다른 개수의 단어로 이루어진 문장을 같은 길이로 만들어주기 위해 패딩을 사용
#   - padding = 'post' : [[ 0  0  0  5  3  2  4], [ 0  0  0  5  3  2  7],...,]
#   - padding = 'pre' : 뒤 부터 패딩이 채워짐
#   - 가장 긴 sequence 의 길이 만큼

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %% [markdown]
# ### **전처리된 타겟 문장과 입력 문장 쌍을 생성**
# - input_tensor : input 문장의 패딩 처리된 숫자 시퀀스
# - inp_lang_tokenizer : input 문장을 공백 단위로 토큰화, 문자 -> 리스트 변환
# - target_tensor, targ_lang_tokenizer : 위와 비슷

# %%
def load_dataset(path, num_examples=None):
  
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### **언어 데이터셋 크기 제한**
# - 언어 데이터셋을 아래의 크기로 제한하여 훈련과 검증을 수행
# - inp_lang, targ_lang : 인풋,타겟 문장의 문자 -> 리스트 변환 결과
# - max_length_targ, max_length_inp : 인풋, 타겟 문장의 '패딩된' 숫자 시퀀스 길이 -> 타겟 텐서와 입력 텐서의 최대 길이

# %%
# num_examples = 30000
num_examples = 60000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file_esb, num_examples)

max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %% [markdown]
# ### **데이터셋 (테스트 & 검증) 분리**

# %%
# 훈련 집합과 검증 집합을 80대 20으로 분리합니다.
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# 훈련 집합과 검증 집합의 데이터 크기를 출력합니다.
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 48000 48000 12000 12000

# %% [markdown]
# ### 인덱스 -> 해당 word 로
#
# ```
# Input Language; index to word mapping
# 1 ----> <start>
# 93 ----> tomas
# 27 ----> le
# 1063 ----> escribio
# 7 ----> a
# 120 ----> maria
# 3 ----> .
# 2 ----> <end>
# ```
#
#
# ```
# Target Language; index to word mapping
# 1 ----> <start>
# 8 ----> tom
# 695 ----> wrote
# 6 ----> to
# 31 ----> mary
# 3 ----> .
# 2 ----> <end>
# ```

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %% [markdown]
# ### **Buffer, Batch, epoch, embedding dimension, units 설정**
# - Tokenizer 의 word_index 속성 : 속성은 단어와 숫자의 키-값 쌍을 포함하는 딕셔너리를 반환
# - 따라서 vocab_inp_size, vocab_inp_size : 인풋, 타겟의 단어-숫자 딕셔너리 최대 길이 + 1 (?)
# - dataset.batch(BATCH_SIZE, drop_remainder = True) : 배치사이즈 만큼 분할 후 남은 데이터를 drop 할 것인지 여부
# - shuffle : 데이터셋 적절히 섞어준다.

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

# 훈련 집합에서만 shuffle, batch
dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 53]), TensorShape([64, 51]))

# %% [markdown]
# ### **Encoder**
#
#
# 1.   초기화 : vocab_size(단어의 크기), embedding_dim(임베딩 차원 수), enc_units(인코더의 히든 사이즈), batch_sz(배치 사이즈)
#   - embedding_dim : 단어 -> 임베딩 벡터로 하기 위한 차원 수
# 2.  call : gru 에 들어가 output, state 출력
# 3.  initialize_hidden_state : 맨 처음 gru에 들어가기 위한 더미 입력 값

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %% [markdown]
# ### **Encoder 객체 생성**

# %%
# encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **Attention**

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # 쿼리 은닉 상태(query hidden state)는 (batch_size, hidden size)쌍으로 이루어져 있습니다.
    # query_with_time_axis은 (batch_size, 1, hidden size)쌍으로 이루어져 있습니다.
    # values는 (batch_size, max_len, hidden size)쌍으로 이루어져 있습니다.
    # 스코어(score)계산을 위해 덧셈을 수행하고자 시간 축을 확장하여 아래의 과정을 수행합니다.
    query_with_time_axis = tf.expand_dims(query, 1)

    # score는 (batch_size, max_length, 1)쌍으로 이루어져 있습니다.
    # score를 self.V에 적용하기 때문에 마지막 축에 1을 얻습니다.
    # self.V에 적용하기 전에 텐서는 (batch_size, max_length, units)쌍으로 이루어져 있습니다.
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights는 (batch_size, max_length, 1)쌍으로 이루어져 있습니다. 
    attention_weights = tf.nn.softmax(score, axis=1)

    # 덧셈이후 컨텍스트 벡터(context_vector)는 (batch_size, hidden_size)쌍으로 이루어져 있습니다.
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %% [markdown]
# ### **Decoder**
#
#
# 1.   초기화 : vocab_size(단어의 크기), embedding_dim(임베딩 차원 수), enc_units(인코더의 히든 사이즈), batch_sz(배치 사이즈)
# 2.   encoder 와의 차이점 : 마지막 fully_connected_layer(tf.keras.layers.Dense) 추가

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # 어텐션을 사용합니다.
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output는 (batch_size, max_length, hidden_size)쌍으로 이루어져 있습니다.
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # 임베딩층을 통과한 후 x는 (batch_size, 1, embedding_dim)쌍으로 이루어져 있습니다.
    x = self.embedding(x)

    # 컨텍스트 벡터와 임베딩 결과를 결합한 이후 x의 형태는 (batch_size, 1, embedding_dim + hidden_size)쌍으로 이루어져 있습니다.
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # 위에서 결합된 벡터를 GRU에 전달합니다.
    output, state = self.gru(x)

    # output은 (batch_size * 1, hidden_size)쌍으로 이루어져 있습니다.
    output = tf.reshape(output, (-1, output.shape[2]))

    # output은 (batch_size, vocab)쌍으로 이루어져 있습니다.
    x = self.fc(output)

    # return x, state, attention_weights
    return x, state

# %% [markdown]
# ### **Decoder 객체 생성**

# %%
# decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **NMT Model 생성**

# %%
class NMT_Model():
  def __init__(self):
    super(NMT_Model, self).__init__()
    self.encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
    self.decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **Ensemble Model 생성**

# %%
models = []
num_models = 5
for m in range(num_models):
  m = NMT_Model()
  models.append(m)

# %% [markdown]
# ### **Loss Function & Optimizer**

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ### **Chekcpoint**
# - 여기서 학습한 매개변수를 저장, optimizer/encoder/decoder

# %%
checkpoint_dir = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/training_checkpoints_esb'
checkpoint_dir_test = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/training_checkpoints_esb2'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoints = []

for m in range(num_models):
  checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=models[m].encoder,
                                 decoder=models[m].decoder)
  checkpoints.append(checkpoint)

# %%
print(checkpoints)
# Out:
# [<tensorflow.python.training.tracking.util.Checkpoint object at 0x7fc79324d710>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7fc79324d748>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7fc79324d7f0>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7fc79324d940>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7fc79324da20>]

# %% [markdown]
# ### **Train_step**

# %%
# @tf.function
def train_step(model, inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = model.encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # 교사 강요(teacher forcing) - 다음 입력으로 타겟을 피딩(feeding)합니다.
    for t in range(1, targ.shape[1]):
      # enc_output를 디코더에 전달합니다.
      predictions, dec_hidden = model.decoder(dec_input, dec_hidden, enc_output)
      # print('predictions', predictions.shape)

      loss += loss_function(targ[:, t], predictions)

      # 교사 강요(teacher forcing)를 사용합니다. -> 훈련에서는 실제 값을 이용
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))
  variables = model.encoder.trainable_variables + model.decoder.trainable_variables
  gradients = tape.gradient(loss, variables)
  optimizer.apply_gradients(zip(gradients, variables))
  return batch_loss

# %% [markdown]
# ### **학습**
# - 학습 코드 X

# %% [markdown]
# ### **문장 번역(스페인 -> 영어)**
#
# *   tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen='', padding='post') : 일정한 길이(maxlen)로 맞춰준다. (패딩은 뒤에서)
# *
#
#   ```
#   inp_lang.word_index :  {'<start>': 1, '<end>': 2, '.': 3, 'tom': 4, '?': 5...}
#   ```
#
# * tf.expand_dims: 차원을 늘려준다.

# %%
def evaluate(sentence):

  sentence = preprocess_sentence(sentence)

  # 문장, input 딕셔너리 출력 
  print ('sentence:', sentence)

  no_word = 'no word'
  inputs = []
  inputs2 = []
  inputs3 = []
  inputs4 = []
  inputs5 = [] 
    
  for i in sentence.split(' '):
    if i in inp_lang.word_index:
        inputs.append(inp_lang.word_index[i])
        inputs2.append(inp_lang.word_index[i])
        inputs3.append(inp_lang.word_index[i])
        inputs4.append(inp_lang.word_index[i])
        inputs5.append(inp_lang.word_index[i])
    else:
        print('no words!')
        return no_word, no_word, no_word, no_word, no_word, no_word, sentence

#   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
#   inputs2 = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs2 = tf.keras.preprocessing.sequence.pad_sequences([inputs2],
                                                         maxlen=max_length_inp,
                                                         padding='post')
#   inputs3 = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs3 = tf.keras.preprocessing.sequence.pad_sequences([inputs3],
                                                         maxlen=max_length_inp,
                                                         padding='post')
#   inputs4 = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs4 = tf.keras.preprocessing.sequence.pad_sequences([inputs4],
                                                         maxlen=max_length_inp,
                                                         padding='post')
#   inputs5 = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs5 = tf.keras.preprocessing.sequence.pad_sequences([inputs5],
                                                         maxlen=max_length_inp,
                                                         padding='post')
    
  inputs = tf.convert_to_tensor(inputs)
  inputs2 = tf.convert_to_tensor(inputs2)
  inputs3 = tf.convert_to_tensor(inputs3)
  inputs4 = tf.convert_to_tensor(inputs2)
  inputs5 = tf.convert_to_tensor(inputs3)


  result1 = ''
  result2 = ''
  result3 = ''
  result4 = ''
  result5 = ''
  voting_result = ''

  hidden = [tf.zeros((1, units))]
  hidden2 = [tf.zeros((1, units))]
  hidden3 = [tf.zeros((1, units))]
  hidden4 = [tf.zeros((1, units))]
  hidden5 = [tf.zeros((1, units))]

  # Encoder 의 hidden 을 Decoder 의 hidden 으로 받는다.
  enc_out, enc_hidden = models[0].encoder(inputs, hidden)

  enc_out2, enc_hidden2 = models[1].encoder(inputs2, hidden2)

  enc_out3, enc_hidden3 = models[2].encoder(inputs3, hidden3)

  enc_out4, enc_hidden4 = models[3].encoder(inputs4, hidden4)

  enc_out5, enc_hidden5 = models[4].encoder(inputs5, hidden5)



  dec_hidden = enc_hidden
  dec_hidden2 = enc_hidden2
  dec_hidden3 = enc_hidden3
  dec_hidden4 = enc_hidden4
  dec_hidden5 = enc_hidden5



  # Decoder 의 시작인 '<start>' 
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)
  dec_input2 = tf.expand_dims([targ_lang.word_index['<start>']], 0)
  dec_input3 = tf.expand_dims([targ_lang.word_index['<start>']], 0)
  dec_input4 = tf.expand_dims([targ_lang.word_index['<start>']], 0)
  dec_input5 = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  # Target 의 최대 길이 만큼 출력
  for t in range(max_length_inp):
    predictions, dec_hidden = models[0].decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)
    predictions2, dec_hidden2 = models[1].decoder(dec_input2,
                                                         dec_hidden2,
                                                         enc_out2)
    predictions3, dec_hidden3 = models[2].decoder(dec_input3,
                                                         dec_hidden3,
                                                         enc_out3)
    predictions4, dec_hidden4 = models[3].decoder(dec_input4,
                                                         dec_hidden4,
                                                         enc_out4)
    predictions5, dec_hidden5 = models[4].decoder(dec_input5,
                                                         dec_hidden5,
                                                         enc_out5)
    
    
    predicted_id = tf.argmax(predictions[0]).numpy() 
    predicted_id2 = tf.argmax(predictions2[0]).numpy() 
    predicted_id3 = tf.argmax(predictions3[0]).numpy() 
    predicted_id4 = tf.argmax(predictions4[0]).numpy() 
    predicted_id5 = tf.argmax(predictions5[0]).numpy()
    
    # Soft Voting
    predictions_sum = tf.add(predictions[0], predictions2[0], predictions3[0])
    predictions_sum = tf.add(predictions_sum, predictions4[0], predictions5[0])
    mean = tf.divide(predictions_sum, 5)
    voting_id = tf.argmax(mean).numpy()

    # tensorflow 에서 .numpy(): Tensor -> Numpy 로 바꿔주는 역할
    # predictions[0]  = tf.Tensor([-7.6920695 -7.9410057  3.7609155 ... ])

    print('p1 : ', predicted_id, mean[predicted_id])
    print('p2 : ', predicted_id2, mean[predicted_id2])
    print('p3 : ', predicted_id3, mean[predicted_id3])
    print('p4 : ', predicted_id4, mean[predicted_id4])
    print('p5 : ', predicted_id5, mean[predicted_id5])
    print('voting : ', voting_id, mean[voting_id])
    
    result1 += targ_lang.index_word[predicted_id] + ' '
    result2 += targ_lang.index_word[predicted_id2] + ' '
    result3 += targ_lang.index_word[predicted_id3] + ' '
    result4 += targ_lang.index_word[predicted_id4] + ' '
    result5 += targ_lang.index_word[predicted_id5] + ' '
    voting_result += targ_lang.index_word[voting_id] + ' '


    if targ_lang.index_word[voting_id] == '<end>':
      return result1, result2, result3, result4, result5, voting_result, sentence

    # 예측된 ID를 모델에 다시 피드합니다. (voting_id)
    dec_input = tf.expand_dims([voting_id], 0)
    dec_input2 = tf.expand_dims([voting_id], 0)
    dec_input3 = tf.expand_dims([voting_id], 0)
    dec_input4 = tf.expand_dims([voting_id], 0)
    dec_input5 = tf.expand_dims([voting_id], 0)

  return result1, result2, result3, result4, result5, voting_result, sentence

# %%
def translate(sentence, start_row):
    result1, result2, result3, result4, result5, voting_result, sentence = evaluate(sentence)
    result_list = [('Model 1', result1),
                   ('Model 2', result2),
                   ('Model 3', result3),
                   ('Model 4', result4),
                   ('Model 5', result5),
                   ('SoftVoting', voting_result)]
        
    # 엑셀 파일 불러오기
    wb = openpyxl.load_workbook('Accuracy_Compare.xlsx')

    # 엑셀 파일의 시트 활성화
    sheet = wb['SoftVoting(2)']

    
    for (model, item) in enumerate(result_list):
        if item[0] != 'SoftVoting':
            sheet.cell(row = start_row + model, column = 5).value = item[1]
        else :    
            sheet.cell(row = start_row + model, column = 6).value = item[1]
        
    
    wb.save('Accuracy_Compare.xlsx')

# %% [markdown]
# ### **Checkpoint 복원**

# %%
ckp_dir_m1 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb'
ckp_dir_m2 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 2'
ckp_dir_m3 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 3'
ckp_dir_m4 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 4'
ckp_dir_m5 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 5'

# %%
# checkpoint_dir내에 있는 최근 체크포인트(checkpoint)를 복원
checkpoints[0].restore(tf.train.latest_checkpoint(ckp_dir_m1))
checkpoints[1].restore(tf.train.latest_checkpoint(ckp_dir_m2))
checkpoints[2].restore(tf.train.latest_checkpoint(ckp_dir_m3))
checkpoints[3].restore(tf.train.latest_checkpoint(ckp_dir_m4))
checkpoints[4].restore(tf.train.latest_checkpoint(ckp_dir_m5))

### 이 코드로 했을 때 학습 바로 돌렸을 때와 같은 결과가 나왔음.

# %% [markdown]
# ### **번역 시작**

# %%
# test dataset 파일 불러오기
testdata = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/Test_Dataset/test_data.txt'
start_row = 2

f = open(testdata, 'r')
lines = f.readlines()

for sentence in lines:
    translate(sentence, start_row)
    start_row += 6
    
f.close()
# Out:
# sentence: <start> te dijeron lo que paso , ¿ no ? <end>
# p1 :  7 tf.Tensor(7.67542, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(7.67542, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(7.67542, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(7.67542, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(7.67542, shape=(), dtype=float32)
# voting :  7 tf.Tensor(7.67542, shape=(), dtype=float32)
# p1 :  123 tf.Tensor(6.324853, shape=(), dtype=float32)
# p2 :  124 tf.Tensor(6.129024, shape=(), dtype=float32)
# p3 :  124 tf.Tensor(6.129024, shape=(), dtype=float32)
# p4 :  77 tf.Tensor(5.012906, shape=(), dtype=float32)
# p5 :  123 tf.Tensor(6.324853, shape=(), dtype=float32)
# voting :  123 tf.Tensor(6.324853, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(8.340616, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(8.340616, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(8.340616, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(8.340616, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(8.340616, shape=(), dtype=float32)
# voting :  7 tf.Tensor(8.340616, shape=(), dtype=float32)
# p1 :  29 tf.Tensor(7.4944177, shape=(), dtype=float32)
# p2 :  29 tf.Tensor(7.4944177, shape=(), dtype=float32)
# p3 :  29 tf.Tensor(7.4944177, shape=(), dtype=float32)
# p4 :  29 tf.Tensor(7.4944177, shape=(), dtype=float32)
# p5 :  29 tf.Tensor(7.4944177, shape=(), dtype=float32)
# voting :  29 tf.Tensor(7.4944177, shape=(), dtype=float32)
# p1 :  234 tf.Tensor(8.802243, shape=(), dtype=float32)
# p2 :  234 tf.Tensor(8.802243, shape=(), dtype=float32)
# p3 :  234 tf.Tensor(8.802243, shape=(), dtype=float32)
# p4 :  234 tf.Tensor(8.802243, shape=(), dtype=float32)
# p5 :  234 tf.Tensor(8.802243, shape=(), dtype=float32)
# voting :  234 tf.Tensor(8.802243, shape=(), dtype=float32)
# p1 :  20 tf.Tensor(8.02814, shape=(), dtype=float32)
# p2 :  20 tf.Tensor(8.02814, shape=(), dtype=float32)
# p3 :  62 tf.Tensor(3.7618515, shape=(), dtype=float32)
# p4 :  20 tf.Tensor(8.02814, shape=(), dtype=float32)
# p5 :  20 tf.Tensor(8.02814, shape=(), dtype=float32)
# voting :  20 tf.Tensor(8.02814, shape=(), dtype=float32)
# p1 :  129 tf.Tensor(4.505666, shape=(), dtype=float32)
# p2 :  55 tf.Tensor(5.8139014, shape=(), dtype=float32)
# p3 :  55 tf.Tensor(5.8139014, shape=(), dtype=float32)
# p4 :  55 tf.Tensor(5.8139014, shape=(), dtype=float32)
# p5 :  141 tf.Tensor(3.853011, shape=(), dtype=float32)
# voting :  55 tf.Tensor(5.8139014, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(7.9946427, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(7.9946427, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(7.9946427, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(7.9946427, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(7.9946427, shape=(), dtype=float32)
# voting :  7 tf.Tensor(7.9946427, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(8.468595, shape=(), dtype=float32)
# p2 :  10 tf.Tensor(8.468595, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(8.468595, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(8.468595, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(8.468595, shape=(), dtype=float32)
# voting :  10 tf.Tensor(8.468595, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.9958515, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.9958515, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.9958515, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.9958515, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.9958515, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.9958515, shape=(), dtype=float32)
# sentence: <start> ellos no estaban alla . <end>
# p1 :  48 tf.Tensor(9.907394, shape=(), dtype=float32)
# p2 :  48 tf.Tensor(9.907394, shape=(), dtype=float32)
# p3 :  48 tf.Tensor(9.907394, shape=(), dtype=float32)
# p4 :  48 tf.Tensor(9.907394, shape=(), dtype=float32)
# p5 :  48 tf.Tensor(9.907394, shape=(), dtype=float32)
# voting :  48 tf.Tensor(9.907394, shape=(), dtype=float32)
# p1 :  77 tf.Tensor(8.778532, shape=(), dtype=float32)
# p2 :  77 tf.Tensor(8.778532, shape=(), dtype=float32)
# p3 :  77 tf.Tensor(8.778532, shape=(), dtype=float32)
# p4 :  77 tf.Tensor(8.778532, shape=(), dtype=float32)
# p5 :  77 tf.Tensor(8.778532, shape=(), dtype=float32)
# voting :  77 tf.Tensor(8.778532, shape=(), dtype=float32)
# p1 :  41 tf.Tensor(7.559273, shape=(), dtype=float32)
# p2 :  41 tf.Tensor(7.559273, shape=(), dtype=float32)
# p3 :  41 tf.Tensor(7.559273, shape=(), dtype=float32)
# p4 :  41 tf.Tensor(7.559273, shape=(), dtype=float32)
# p5 :  41 tf.Tensor(7.559273, shape=(), dtype=float32)
# voting :  41 tf.Tensor(7.559273, shape=(), dtype=float32)
# p1 :  47 tf.Tensor(8.086577, shape=(), dtype=float32)
# p2 :  47 tf.Tensor(8.086577, shape=(), dtype=float32)
# p3 :  47 tf.Tensor(8.086577, shape=(), dtype=float32)
# p4 :  47 tf.Tensor(8.086577, shape=(), dtype=float32)
# p5 :  47 tf.Tensor(8.086577, shape=(), dtype=float32)
# voting :  47 tf.Tensor(8.086577, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(8.865511, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(8.865511, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(8.865511, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(8.865511, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(8.865511, shape=(), dtype=float32)
# voting :  3 tf.Tensor(8.865511, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.458441, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.458441, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.458441, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.458441, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.458441, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.458441, shape=(), dtype=float32)
# sentence: <start> no me gusta ninguno de los chicos . <end>
# p1 :  4 tf.Tensor(8.966354, shape=(), dtype=float32)
# p2 :  4 tf.Tensor(8.966354, shape=(), dtype=float32)
# p3 :  4 tf.Tensor(8.966354, shape=(), dtype=float32)
# p4 :  4 tf.Tensor(8.966354, shape=(), dtype=float32)
# p5 :  4 tf.Tensor(8.966354, shape=(), dtype=float32)
# voting :  4 tf.Tensor(8.966354, shape=(), dtype=float32)
# p1 :  30 tf.Tensor(8.614716, shape=(), dtype=float32)
# p2 :  30 tf.Tensor(8.614716, shape=(), dtype=float32)
# p3 :  30 tf.Tensor(8.614716, shape=(), dtype=float32)
# p4 :  30 tf.Tensor(8.614716, shape=(), dtype=float32)
# p5 :  30 tf.Tensor(8.614716, shape=(), dtype=float32)
# voting :  30 tf.Tensor(8.614716, shape=(), dtype=float32)
# p1 :  12 tf.Tensor(12.976071, shape=(), dtype=float32)
# p2 :  12 tf.Tensor(12.976071, shape=(), dtype=float32)
# p3 :  12 tf.Tensor(12.976071, shape=(), dtype=float32)
# p4 :  12 tf.Tensor(12.976071, shape=(), dtype=float32)
# p5 :  12 tf.Tensor(12.976071, shape=(), dtype=float32)
# voting :  12 tf.Tensor(12.976071, shape=(), dtype=float32)
# p1 :  43 tf.Tensor(9.786786, shape=(), dtype=float32)
# p2 :  43 tf.Tensor(9.786786, shape=(), dtype=float32)
# p3 :  43 tf.Tensor(9.786786, shape=(), dtype=float32)
# p4 :  43 tf.Tensor(9.786786, shape=(), dtype=float32)
# p5 :  43 tf.Tensor(9.786786, shape=(), dtype=float32)
# voting :  43 tf.Tensor(9.786786, shape=(), dtype=float32)
# p1 :  135 tf.Tensor(5.9167585, shape=(), dtype=float32)
# p2 :  314 tf.Tensor(6.0089293, shape=(), dtype=float32)
# p3 :  135 tf.Tensor(5.9167585, shape=(), dtype=float32)
# p4 :  314 tf.Tensor(6.0089293, shape=(), dtype=float32)
# p5 :  314 tf.Tensor(6.0089293, shape=(), dtype=float32)
# voting :  314 tf.Tensor(6.0089293, shape=(), dtype=float32)
# p1 :  18 tf.Tensor(7.7804384, shape=(), dtype=float32)
# p2 :  18 tf.Tensor(7.7804384, shape=(), dtype=float32)
# p3 :  18 tf.Tensor(7.7804384, shape=(), dtype=float32)
# p4 :  18 tf.Tensor(7.7804384, shape=(), dtype=float32)
# p5 :  18 tf.Tensor(7.7804384, shape=(), dtype=float32)
# voting :  18 tf.Tensor(7.7804384, shape=(), dtype=float32)
# p1 :  745 tf.Tensor(6.863135, shape=(), dtype=float32)
# p2 :  745 tf.Tensor(6.863135, shape=(), dtype=float32)
# p3 :  745 tf.Tensor(6.863135, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(5.797873, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(5.797873, shape=(), dtype=float32)
# voting :  745 tf.Tensor(6.863135, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(6.591226, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(6.591226, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(6.591226, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(6.591226, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(6.591226, shape=(), dtype=float32)
# voting :  3 tf.Tensor(6.591226, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.680263, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.680263, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.680263, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.680263, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.680263, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.680263, shape=(), dtype=float32)
# sentence: <start> jamas trabaje con el . <end>
# p1 :  4 tf.Tensor(8.77012, shape=(), dtype=float32)
# p2 :  4 tf.Tensor(8.77012, shape=(), dtype=float32)
# p3 :  4 tf.Tensor(8.77012, shape=(), dtype=float32)
# p4 :  4 tf.Tensor(8.77012, shape=(), dtype=float32)
# p5 :  4 tf.Tensor(8.77012, shape=(), dtype=float32)
# voting :  4 tf.Tensor(8.77012, shape=(), dtype=float32)
# p1 :  97 tf.Tensor(7.689784, shape=(), dtype=float32)
# p2 :  69 tf.Tensor(6.6632996, shape=(), dtype=float32)
# p3 :  69 tf.Tensor(6.6632996, shape=(), dtype=float32)
# p4 :  97 tf.Tensor(7.689784, shape=(), dtype=float32)
# p5 :  69 tf.Tensor(6.6632996, shape=(), dtype=float32)
# voting :  97 tf.Tensor(7.689784, shape=(), dtype=float32)
# p1 :  115 tf.Tensor(4.3600664, shape=(), dtype=float32)
# p2 :  707 tf.Tensor(3.2759273, shape=(), dtype=float32)
# p3 :  68 tf.Tensor(2.6408417, shape=(), dtype=float32)
# p4 :  139 tf.Tensor(2.8322027, shape=(), dtype=float32)
# p5 :  707 tf.Tensor(3.2759273, shape=(), dtype=float32)
# voting :  115 tf.Tensor(4.3600664, shape=(), dtype=float32)
# p1 :  39 tf.Tensor(7.7788253, shape=(), dtype=float32)
# p2 :  39 tf.Tensor(7.7788253, shape=(), dtype=float32)
# p3 :  39 tf.Tensor(7.7788253, shape=(), dtype=float32)
# p4 :  39 tf.Tensor(7.7788253, shape=(), dtype=float32)
# p5 :  39 tf.Tensor(7.7788253, shape=(), dtype=float32)
# voting :  39 tf.Tensor(7.7788253, shape=(), dtype=float32)
# p1 :  46 tf.Tensor(9.076721, shape=(), dtype=float32)
# p2 :  46 tf.Tensor(9.076721, shape=(), dtype=float32)
# p3 :  46 tf.Tensor(9.076721, shape=(), dtype=float32)
# p4 :  46 tf.Tensor(9.076721, shape=(), dtype=float32)
# p5 :  46 tf.Tensor(9.076721, shape=(), dtype=float32)
# voting :  46 tf.Tensor(9.076721, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.20488, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.20488, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.20488, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.20488, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.20488, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.20488, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.589804, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.589804, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.589804, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.589804, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.589804, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.589804, shape=(), dtype=float32)
# sentence: <start> mi padre cultiva arroz . <end>
# p1 :  25 tf.Tensor(9.042433, shape=(), dtype=float32)
# p2 :  25 tf.Tensor(9.042433, shape=(), dtype=float32)
# p3 :  25 tf.Tensor(9.042433, shape=(), dtype=float32)
# p4 :  25 tf.Tensor(9.042433, shape=(), dtype=float32)
# p5 :  25 tf.Tensor(9.042433, shape=(), dtype=float32)
# voting :  25 tf.Tensor(9.042433, shape=(), dtype=float32)
# p1 :  150 tf.Tensor(10.220221, shape=(), dtype=float32)
# p2 :  150 tf.Tensor(10.220221, shape=(), dtype=float32)
# p3 :  150 tf.Tensor(10.220221, shape=(), dtype=float32)
# p4 :  150 tf.Tensor(10.220221, shape=(), dtype=float32)
# p5 :  150 tf.Tensor(10.220221, shape=(), dtype=float32)
# voting :  150 tf.Tensor(10.220221, shape=(), dtype=float32)
# p1 :  4528 tf.Tensor(5.352671, shape=(), dtype=float32)
# p2 :  972 tf.Tensor(5.495932, shape=(), dtype=float32)
# p3 :  1045 tf.Tensor(4.102721, shape=(), dtype=float32)
# p4 :  1283 tf.Tensor(5.2147684, shape=(), dtype=float32)
# p5 :  51 tf.Tensor(5.866063, shape=(), dtype=float32)
# voting :  137 tf.Tensor(6.0836005, shape=(), dtype=float32)
# p1 :  25 tf.Tensor(3.1648316, shape=(), dtype=float32)
# p2 :  1120 tf.Tensor(4.433099, shape=(), dtype=float32)
# p3 :  557 tf.Tensor(2.9239624, shape=(), dtype=float32)
# p4 :  557 tf.Tensor(2.9239624, shape=(), dtype=float32)
# p5 :  1120 tf.Tensor(4.433099, shape=(), dtype=float32)
# voting :  1120 tf.Tensor(4.433099, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(7.7437196, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(7.7437196, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(7.7437196, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(7.7437196, shape=(), dtype=float32)
# p5 :  5680 tf.Tensor(0.6615003, shape=(), dtype=float32)
# voting :  3 tf.Tensor(7.7437196, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.049002, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.049002, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.049002, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.049002, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.049002, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.049002, shape=(), dtype=float32)
# sentence: <start> dime que hiciste en shounan . <end>
# p1 :  99 tf.Tensor(7.3507547, shape=(), dtype=float32)
# p2 :  99 tf.Tensor(7.3507547, shape=(), dtype=float32)
# p3 :  99 tf.Tensor(7.3507547, shape=(), dtype=float32)
# p4 :  99 tf.Tensor(7.3507547, shape=(), dtype=float32)
# p5 :  99 tf.Tensor(7.3507547, shape=(), dtype=float32)
# voting :  99 tf.Tensor(7.3507547, shape=(), dtype=float32)
# p1 :  24 tf.Tensor(10.655321, shape=(), dtype=float32)
# p2 :  24 tf.Tensor(10.655321, shape=(), dtype=float32)
# p3 :  24 tf.Tensor(10.655321, shape=(), dtype=float32)
# p4 :  24 tf.Tensor(10.655321, shape=(), dtype=float32)
# p5 :  24 tf.Tensor(10.655321, shape=(), dtype=float32)
# voting :  24 tf.Tensor(10.655321, shape=(), dtype=float32)
# p1 :  29 tf.Tensor(8.22892, shape=(), dtype=float32)
# p2 :  29 tf.Tensor(8.22892, shape=(), dtype=float32)
# p3 :  29 tf.Tensor(8.22892, shape=(), dtype=float32)
# p4 :  29 tf.Tensor(8.22892, shape=(), dtype=float32)
# p5 :  29 tf.Tensor(8.22892, shape=(), dtype=float32)
# voting :  29 tf.Tensor(8.22892, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(8.799454, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(8.799454, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(8.799454, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(8.799454, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(8.799454, shape=(), dtype=float32)
# voting :  7 tf.Tensor(8.799454, shape=(), dtype=float32)
# p1 :  55 tf.Tensor(8.317845, shape=(), dtype=float32)
# p2 :  55 tf.Tensor(8.317845, shape=(), dtype=float32)
# p3 :  55 tf.Tensor(8.317845, shape=(), dtype=float32)
# p4 :  55 tf.Tensor(8.317845, shape=(), dtype=float32)
# p5 :  55 tf.Tensor(8.317845, shape=(), dtype=float32)
# voting :  55 tf.Tensor(8.317845, shape=(), dtype=float32)
# p1 :  16 tf.Tensor(5.403809, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(2.3653035, shape=(), dtype=float32)
# p3 :  16 tf.Tensor(5.403809, shape=(), dtype=float32)
# p4 :  16 tf.Tensor(5.403809, shape=(), dtype=float32)
# p5 :  6 tf.Tensor(2.7449791, shape=(), dtype=float32)
# voting :  16 tf.Tensor(5.403809, shape=(), dtype=float32)
# p1 :  2150 tf.Tensor(3.3968468, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(3.3025818, shape=(), dtype=float32)
# p3 :  286 tf.Tensor(3.3716698, shape=(), dtype=float32)
# p4 :  2067 tf.Tensor(2.8303826, shape=(), dtype=float32)
# p5 :  415 tf.Tensor(2.8423355, shape=(), dtype=float32)
# voting :  2150 tf.Tensor(3.3968468, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(11.10506, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(11.10506, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(11.10506, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(11.10506, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(11.10506, shape=(), dtype=float32)
# voting :  3 tf.Tensor(11.10506, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.74864, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.74864, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.74864, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.74864, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.74864, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.74864, shape=(), dtype=float32)
# sentence: <start> ¿ cuantas palabras deberias escribir ? <end>
# p1 :  54 tf.Tensor(9.719891, shape=(), dtype=float32)
# p2 :  54 tf.Tensor(9.719891, shape=(), dtype=float32)
# p3 :  54 tf.Tensor(9.719891, shape=(), dtype=float32)
# p4 :  54 tf.Tensor(9.719891, shape=(), dtype=float32)
# p5 :  54 tf.Tensor(9.719891, shape=(), dtype=float32)
# voting :  54 tf.Tensor(9.719891, shape=(), dtype=float32)
# p1 :  131 tf.Tensor(9.713636, shape=(), dtype=float32)
# p2 :  131 tf.Tensor(9.713636, shape=(), dtype=float32)
# p3 :  131 tf.Tensor(9.713636, shape=(), dtype=float32)
# p4 :  131 tf.Tensor(9.713636, shape=(), dtype=float32)
# p5 :  131 tf.Tensor(9.713636, shape=(), dtype=float32)
# voting :  131 tf.Tensor(9.713636, shape=(), dtype=float32)
# p1 :  812 tf.Tensor(4.66648, shape=(), dtype=float32)
# p2 :  18 tf.Tensor(5.465104, shape=(), dtype=float32)
# p3 :  18 tf.Tensor(5.465104, shape=(), dtype=float32)
# p4 :  565 tf.Tensor(3.3363006, shape=(), dtype=float32)
# p5 :  117 tf.Tensor(3.553262, shape=(), dtype=float32)
# voting :  18 tf.Tensor(5.465104, shape=(), dtype=float32)
# p1 :  35 tf.Tensor(3.1904042, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(4.8585534, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(3.6914513, shape=(), dtype=float32)
# p4 :  54 tf.Tensor(3.5469022, shape=(), dtype=float32)
# p5 :  2447 tf.Tensor(0.9535782, shape=(), dtype=float32)
# voting :  7 tf.Tensor(4.8585534, shape=(), dtype=float32)
# p1 :  101 tf.Tensor(7.6876016, shape=(), dtype=float32)
# p2 :  101 tf.Tensor(7.6876016, shape=(), dtype=float32)
# p3 :  101 tf.Tensor(7.6876016, shape=(), dtype=float32)
# p4 :  122 tf.Tensor(3.9744925, shape=(), dtype=float32)
# p5 :  296 tf.Tensor(1.6028354, shape=(), dtype=float32)
# voting :  101 tf.Tensor(7.6876016, shape=(), dtype=float32)
# p1 :  4 tf.Tensor(3.7234726, shape=(), dtype=float32)
# p2 :  391 tf.Tensor(6.848787, shape=(), dtype=float32)
# p3 :  23 tf.Tensor(2.930411, shape=(), dtype=float32)
# p4 :  391 tf.Tensor(6.848787, shape=(), dtype=float32)
# p5 :  391 tf.Tensor(6.848787, shape=(), dtype=float32)
# voting :  391 tf.Tensor(6.848787, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(8.913945, shape=(), dtype=float32)
# p2 :  6 tf.Tensor(6.3774285, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(8.913945, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(8.913945, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(8.913945, shape=(), dtype=float32)
# voting :  10 tf.Tensor(8.913945, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.880243, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.880243, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.880243, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.880243, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.880243, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.880243, shape=(), dtype=float32)
# sentence: <start> ¿ como te introdujiste en mi casa ? <end>
# p1 :  54 tf.Tensor(9.960555, shape=(), dtype=float32)
# p2 :  54 tf.Tensor(9.960555, shape=(), dtype=float32)
# p3 :  54 tf.Tensor(9.960555, shape=(), dtype=float32)
# p4 :  54 tf.Tensor(9.960555, shape=(), dtype=float32)
# p5 :  54 tf.Tensor(9.960555, shape=(), dtype=float32)
# voting :  54 tf.Tensor(9.960555, shape=(), dtype=float32)
# p1 :  55 tf.Tensor(4.2211394, shape=(), dtype=float32)
# p2 :  63 tf.Tensor(4.8091764, shape=(), dtype=float32)
# p3 :  55 tf.Tensor(4.2211394, shape=(), dtype=float32)
# p4 :  22 tf.Tensor(4.977286, shape=(), dtype=float32)
# p5 :  55 tf.Tensor(4.2211394, shape=(), dtype=float32)
# voting :  22 tf.Tensor(4.977286, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(9.795275, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(9.795275, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(9.795275, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(9.795275, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(9.795275, shape=(), dtype=float32)
# voting :  7 tf.Tensor(9.795275, shape=(), dtype=float32)
# p1 :  49 tf.Tensor(5.4373875, shape=(), dtype=float32)
# p2 :  49 tf.Tensor(5.4373875, shape=(), dtype=float32)
# p3 :  68 tf.Tensor(4.913608, shape=(), dtype=float32)
# p4 :  177 tf.Tensor(4.45097, shape=(), dtype=float32)
# p5 :  107 tf.Tensor(3.2077541, shape=(), dtype=float32)
# voting :  49 tf.Tensor(5.4373875, shape=(), dtype=float32)
# p1 :  36 tf.Tensor(6.3491507, shape=(), dtype=float32)
# p2 :  6 tf.Tensor(6.12068, shape=(), dtype=float32)
# p3 :  6 tf.Tensor(6.12068, shape=(), dtype=float32)
# p4 :  183 tf.Tensor(5.5195084, shape=(), dtype=float32)
# p5 :  76 tf.Tensor(4.4609294, shape=(), dtype=float32)
# voting :  36 tf.Tensor(6.3491507, shape=(), dtype=float32)
# p1 :  25 tf.Tensor(9.144468, shape=(), dtype=float32)
# p2 :  25 tf.Tensor(9.144468, shape=(), dtype=float32)
# p3 :  25 tf.Tensor(9.144468, shape=(), dtype=float32)
# p4 :  25 tf.Tensor(9.144468, shape=(), dtype=float32)
# p5 :  25 tf.Tensor(9.144468, shape=(), dtype=float32)
# voting :  25 tf.Tensor(9.144468, shape=(), dtype=float32)
# p1 :  121 tf.Tensor(8.98011, shape=(), dtype=float32)
# p2 :  121 tf.Tensor(8.98011, shape=(), dtype=float32)
# p3 :  121 tf.Tensor(8.98011, shape=(), dtype=float32)
# p4 :  121 tf.Tensor(8.98011, shape=(), dtype=float32)
# p5 :  121 tf.Tensor(8.98011, shape=(), dtype=float32)
# voting :  121 tf.Tensor(8.98011, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(7.8273954, shape=(), dtype=float32)
# p2 :  10 tf.Tensor(7.8273954, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(7.8273954, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(7.8273954, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(7.8273954, shape=(), dtype=float32)
# voting :  10 tf.Tensor(7.8273954, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.9006195, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.9006195, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.9006195, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.9006195, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.9006195, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.9006195, shape=(), dtype=float32)
# sentence: <start> mi madre hornea pan todas las mananas . <end>
# p1 :  25 tf.Tensor(8.632803, shape=(), dtype=float32)
# p2 :  25 tf.Tensor(8.632803, shape=(), dtype=float32)
# p3 :  25 tf.Tensor(8.632803, shape=(), dtype=float32)
# p4 :  25 tf.Tensor(8.632803, shape=(), dtype=float32)
# p5 :  25 tf.Tensor(8.632803, shape=(), dtype=float32)
# voting :  25 tf.Tensor(8.632803, shape=(), dtype=float32)
# p1 :  188 tf.Tensor(9.747597, shape=(), dtype=float32)
# p2 :  188 tf.Tensor(9.747597, shape=(), dtype=float32)
# p3 :  188 tf.Tensor(9.747597, shape=(), dtype=float32)
# p4 :  188 tf.Tensor(9.747597, shape=(), dtype=float32)
# p5 :  188 tf.Tensor(9.747597, shape=(), dtype=float32)
# voting :  188 tf.Tensor(9.747597, shape=(), dtype=float32)
# p1 :  4270 tf.Tensor(9.074448, shape=(), dtype=float32)
# p2 :  4270 tf.Tensor(9.074448, shape=(), dtype=float32)
# p3 :  4270 tf.Tensor(9.074448, shape=(), dtype=float32)
# p4 :  4270 tf.Tensor(9.074448, shape=(), dtype=float32)
# p5 :  4270 tf.Tensor(9.074448, shape=(), dtype=float32)
# voting :  4270 tf.Tensor(9.074448, shape=(), dtype=float32)
# p1 :  886 tf.Tensor(9.1803465, shape=(), dtype=float32)
# p2 :  886 tf.Tensor(9.1803465, shape=(), dtype=float32)
# p3 :  886 tf.Tensor(9.1803465, shape=(), dtype=float32)
# p4 :  886 tf.Tensor(9.1803465, shape=(), dtype=float32)
# p5 :  886 tf.Tensor(9.1803465, shape=(), dtype=float32)
# voting :  886 tf.Tensor(9.1803465, shape=(), dtype=float32)
# p1 :  60 tf.Tensor(5.8256464, shape=(), dtype=float32)
# p2 :  153 tf.Tensor(8.064685, shape=(), dtype=float32)
# p3 :  153 tf.Tensor(8.064685, shape=(), dtype=float32)
# p4 :  153 tf.Tensor(8.064685, shape=(), dtype=float32)
# p5 :  153 tf.Tensor(8.064685, shape=(), dtype=float32)
# voting :  153 tf.Tensor(8.064685, shape=(), dtype=float32)
# p1 :  212 tf.Tensor(9.858695, shape=(), dtype=float32)
# p2 :  212 tf.Tensor(9.858695, shape=(), dtype=float32)
# p3 :  212 tf.Tensor(9.858695, shape=(), dtype=float32)
# p4 :  212 tf.Tensor(9.858695, shape=(), dtype=float32)
# p5 :  212 tf.Tensor(9.858695, shape=(), dtype=float32)
# voting :  212 tf.Tensor(9.858695, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.69898, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.69898, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.69898, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.69898, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.69898, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.69898, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(10.993364, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(10.993364, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(10.993364, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(10.993364, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(10.993364, shape=(), dtype=float32)
# voting :  2 tf.Tensor(10.993364, shape=(), dtype=float32)
# sentence: <start> yo he disfrutado el leer esta novela . <end>
# p1 :  4 tf.Tensor(8.456511, shape=(), dtype=float32)
# p2 :  4 tf.Tensor(8.456511, shape=(), dtype=float32)
# p3 :  4 tf.Tensor(8.456511, shape=(), dtype=float32)
# p4 :  4 tf.Tensor(8.456511, shape=(), dtype=float32)
# p5 :  4 tf.Tensor(8.456511, shape=(), dtype=float32)
# voting :  4 tf.Tensor(8.456511, shape=(), dtype=float32)
# p1 :  69 tf.Tensor(5.9217534, shape=(), dtype=float32)
# p2 :  994 tf.Tensor(5.7974653, shape=(), dtype=float32)
# p3 :  994 tf.Tensor(5.7974653, shape=(), dtype=float32)
# p4 :  994 tf.Tensor(5.7974653, shape=(), dtype=float32)
# p5 :  994 tf.Tensor(5.7974653, shape=(), dtype=float32)
# voting :  69 tf.Tensor(5.9217534, shape=(), dtype=float32)
# p1 :  136 tf.Tensor(4.419027, shape=(), dtype=float32)
# p2 :  100 tf.Tensor(3.9207969, shape=(), dtype=float32)
# p3 :  447 tf.Tensor(2.8361163, shape=(), dtype=float32)
# p4 :  89 tf.Tensor(3.9453888, shape=(), dtype=float32)
# p5 :  143 tf.Tensor(1.382451, shape=(), dtype=float32)
# voting :  136 tf.Tensor(4.419027, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(7.532794, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(7.532794, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(7.532794, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(7.532794, shape=(), dtype=float32)
# p5 :  66 tf.Tensor(4.8021994, shape=(), dtype=float32)
# voting :  5 tf.Tensor(7.532794, shape=(), dtype=float32)
# p1 :  130 tf.Tensor(4.2002077, shape=(), dtype=float32)
# p2 :  389 tf.Tensor(5.0543604, shape=(), dtype=float32)
# p3 :  206 tf.Tensor(4.4809504, shape=(), dtype=float32)
# p4 :  491 tf.Tensor(1.4292097, shape=(), dtype=float32)
# p5 :  165 tf.Tensor(0.20394683, shape=(), dtype=float32)
# voting :  389 tf.Tensor(5.0543604, shape=(), dtype=float32)
# p1 :  21 tf.Tensor(9.357953, shape=(), dtype=float32)
# p2 :  21 tf.Tensor(9.357953, shape=(), dtype=float32)
# p3 :  21 tf.Tensor(9.357953, shape=(), dtype=float32)
# p4 :  21 tf.Tensor(9.357953, shape=(), dtype=float32)
# p5 :  21 tf.Tensor(9.357953, shape=(), dtype=float32)
# voting :  21 tf.Tensor(9.357953, shape=(), dtype=float32)
# p1 :  839 tf.Tensor(7.825554, shape=(), dtype=float32)
# p2 :  839 tf.Tensor(7.825554, shape=(), dtype=float32)
# p3 :  839 tf.Tensor(7.825554, shape=(), dtype=float32)
# p4 :  839 tf.Tensor(7.825554, shape=(), dtype=float32)
# p5 :  839 tf.Tensor(7.825554, shape=(), dtype=float32)
# voting :  839 tf.Tensor(7.825554, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.04451, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.04451, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.04451, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.04451, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.04451, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.04451, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.855261, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.855261, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.855261, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.855261, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.855261, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.855261, shape=(), dtype=float32)
# sentence: <start> el estaba parado en la esquina . <end>
# p1 :  13 tf.Tensor(10.011167, shape=(), dtype=float32)
# p2 :  13 tf.Tensor(10.011167, shape=(), dtype=float32)
# p3 :  13 tf.Tensor(10.011167, shape=(), dtype=float32)
# p4 :  13 tf.Tensor(10.011167, shape=(), dtype=float32)
# p5 :  13 tf.Tensor(10.011167, shape=(), dtype=float32)
# voting :  13 tf.Tensor(10.011167, shape=(), dtype=float32)
# p1 :  19 tf.Tensor(8.224882, shape=(), dtype=float32)
# p2 :  19 tf.Tensor(8.224882, shape=(), dtype=float32)
# p3 :  1086 tf.Tensor(6.9021654, shape=(), dtype=float32)
# p4 :  19 tf.Tensor(8.224882, shape=(), dtype=float32)
# p5 :  1086 tf.Tensor(6.9021654, shape=(), dtype=float32)
# voting :  19 tf.Tensor(8.224882, shape=(), dtype=float32)
# p1 :  974 tf.Tensor(9.278488, shape=(), dtype=float32)
# p2 :  974 tf.Tensor(9.278488, shape=(), dtype=float32)
# p3 :  974 tf.Tensor(9.278488, shape=(), dtype=float32)
# p4 :  974 tf.Tensor(9.278488, shape=(), dtype=float32)
# p5 :  974 tf.Tensor(9.278488, shape=(), dtype=float32)
# voting :  974 tf.Tensor(9.278488, shape=(), dtype=float32)
# p1 :  44 tf.Tensor(8.738072, shape=(), dtype=float32)
# p2 :  44 tf.Tensor(8.738072, shape=(), dtype=float32)
# p3 :  44 tf.Tensor(8.738072, shape=(), dtype=float32)
# p4 :  16 tf.Tensor(7.2632804, shape=(), dtype=float32)
# p5 :  44 tf.Tensor(8.738072, shape=(), dtype=float32)
# voting :  44 tf.Tensor(8.738072, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(8.485918, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(8.485918, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(8.485918, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(8.485918, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(8.485918, shape=(), dtype=float32)
# voting :  5 tf.Tensor(8.485918, shape=(), dtype=float32)
# p1 :  1676 tf.Tensor(9.08109, shape=(), dtype=float32)
# p2 :  1676 tf.Tensor(9.08109, shape=(), dtype=float32)
# p3 :  1676 tf.Tensor(9.08109, shape=(), dtype=float32)
# p4 :  1676 tf.Tensor(9.08109, shape=(), dtype=float32)
# p5 :  1676 tf.Tensor(9.08109, shape=(), dtype=float32)
# voting :  1676 tf.Tensor(9.08109, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.058952, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.058952, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.058952, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.058952, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.058952, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.058952, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.444647, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.444647, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.444647, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.444647, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.444647, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.444647, shape=(), dtype=float32)
# sentence: <start> el testigo no parecia estar nervioso cuando testifico en el juicio . <end>
# p1 :  5 tf.Tensor(7.319783, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(7.319783, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(7.319783, shape=(), dtype=float32)
# p4 :  13 tf.Tensor(5.0626574, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(7.319783, shape=(), dtype=float32)
# voting :  5 tf.Tensor(7.319783, shape=(), dtype=float32)
# p1 :  1281 tf.Tensor(0.5666523, shape=(), dtype=float32)
# p2 :  850 tf.Tensor(2.2187862, shape=(), dtype=float32)
# p3 :  158 tf.Tensor(2.9172301, shape=(), dtype=float32)
# p4 :  1363 tf.Tensor(3.7707908, shape=(), dtype=float32)
# p5 :  158 tf.Tensor(2.9172301, shape=(), dtype=float32)
# voting :  2226 tf.Tensor(4.5885177, shape=(), dtype=float32)
# p1 :  64 tf.Tensor(7.6779037, shape=(), dtype=float32)
# p2 :  636 tf.Tensor(6.6168184, shape=(), dtype=float32)
# p3 :  64 tf.Tensor(7.6779037, shape=(), dtype=float32)
# p4 :  64 tf.Tensor(7.6779037, shape=(), dtype=float32)
# p5 :  64 tf.Tensor(7.6779037, shape=(), dtype=float32)
# voting :  64 tf.Tensor(7.6779037, shape=(), dtype=float32)
# p1 :  12 tf.Tensor(11.891452, shape=(), dtype=float32)
# p2 :  12 tf.Tensor(11.891452, shape=(), dtype=float32)
# p3 :  12 tf.Tensor(11.891452, shape=(), dtype=float32)
# p4 :  12 tf.Tensor(11.891452, shape=(), dtype=float32)
# p5 :  12 tf.Tensor(11.891452, shape=(), dtype=float32)
# voting :  12 tf.Tensor(11.891452, shape=(), dtype=float32)
# p1 :  517 tf.Tensor(6.6302047, shape=(), dtype=float32)
# p2 :  517 tf.Tensor(6.6302047, shape=(), dtype=float32)
# p3 :  517 tf.Tensor(6.6302047, shape=(), dtype=float32)
# p4 :  517 tf.Tensor(6.6302047, shape=(), dtype=float32)
# p5 :  517 tf.Tensor(6.6302047, shape=(), dtype=float32)
# voting :  517 tf.Tensor(6.6302047, shape=(), dtype=float32)
# p1 :  857 tf.Tensor(2.6187387, shape=(), dtype=float32)
# p2 :  6 tf.Tensor(6.5382147, shape=(), dtype=float32)
# p3 :  6 tf.Tensor(6.5382147, shape=(), dtype=float32)
# p4 :  6 tf.Tensor(6.5382147, shape=(), dtype=float32)
# p5 :  6 tf.Tensor(6.5382147, shape=(), dtype=float32)
# voting :  6 tf.Tensor(6.5382147, shape=(), dtype=float32)
# p1 :  197 tf.Tensor(1.8795807, shape=(), dtype=float32)
# p2 :  37 tf.Tensor(6.6109505, shape=(), dtype=float32)
# p3 :  37 tf.Tensor(6.6109505, shape=(), dtype=float32)
# p4 :  981 tf.Tensor(3.2937508, shape=(), dtype=float32)
# p5 :  37 tf.Tensor(6.6109505, shape=(), dtype=float32)
# voting :  37 tf.Tensor(6.6109505, shape=(), dtype=float32)
# p1 :  925 tf.Tensor(5.5815516, shape=(), dtype=float32)
# p2 :  2699 tf.Tensor(5.0600724, shape=(), dtype=float32)
# p3 :  925 tf.Tensor(5.5815516, shape=(), dtype=float32)
# p4 :  542 tf.Tensor(5.0559053, shape=(), dtype=float32)
# p5 :  925 tf.Tensor(5.5815516, shape=(), dtype=float32)
# voting :  925 tf.Tensor(5.5815516, shape=(), dtype=float32)
# p1 :  72 tf.Tensor(9.553821, shape=(), dtype=float32)
# p2 :  72 tf.Tensor(9.553821, shape=(), dtype=float32)
# p3 :  72 tf.Tensor(9.553821, shape=(), dtype=float32)
# p4 :  72 tf.Tensor(9.553821, shape=(), dtype=float32)
# p5 :  72 tf.Tensor(9.553821, shape=(), dtype=float32)
# voting :  72 tf.Tensor(9.553821, shape=(), dtype=float32)
# p1 :  48 tf.Tensor(5.687436, shape=(), dtype=float32)
# p2 :  13 tf.Tensor(4.766207, shape=(), dtype=float32)
# p3 :  13 tf.Tensor(4.766207, shape=(), dtype=float32)
# p4 :  48 tf.Tensor(5.687436, shape=(), dtype=float32)
# p5 :  13 tf.Tensor(4.766207, shape=(), dtype=float32)
# voting :  48 tf.Tensor(5.687436, shape=(), dtype=float32)
# p1 :  53 tf.Tensor(5.1300125, shape=(), dtype=float32)
# p2 :  53 tf.Tensor(5.1300125, shape=(), dtype=float32)
# p3 :  199 tf.Tensor(2.6906269, shape=(), dtype=float32)
# p4 :  467 tf.Tensor(1.972998, shape=(), dtype=float32)
# p5 :  1237 tf.Tensor(-0.60993004, shape=(), dtype=float32)
# voting :  53 tf.Tensor(5.1300125, shape=(), dtype=float32)
# p1 :  36 tf.Tensor(5.698058, shape=(), dtype=float32)
# p2 :  36 tf.Tensor(5.698058, shape=(), dtype=float32)
# p3 :  78 tf.Tensor(4.8170114, shape=(), dtype=float32)
# p4 :  2311 tf.Tensor(3.6788821, shape=(), dtype=float32)
# p5 :  78 tf.Tensor(4.8170114, shape=(), dtype=float32)
# voting :  36 tf.Tensor(5.698058, shape=(), dtype=float32)
# p1 :  6380 tf.Tensor(0.90686524, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(4.73737, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(4.73737, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(4.814765, shape=(), dtype=float32)
# p5 :  1146 tf.Tensor(-0.03814423, shape=(), dtype=float32)
# voting :  5 tf.Tensor(4.814765, shape=(), dtype=float32)
# p1 :  212 tf.Tensor(1.6257603, shape=(), dtype=float32)
# p2 :  2952 tf.Tensor(3.170159, shape=(), dtype=float32)
# p3 :  5012 tf.Tensor(2.0944836, shape=(), dtype=float32)
# p4 :  359 tf.Tensor(3.394088, shape=(), dtype=float32)
# p5 :  2009 tf.Tensor(3.0757926, shape=(), dtype=float32)
# voting :  3141 tf.Tensor(4.064831, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(7.435874, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(7.435874, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(7.435874, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(7.435874, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(7.435874, shape=(), dtype=float32)
# voting :  3 tf.Tensor(7.435874, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(10.860109, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(10.860109, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(10.860109, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(10.860109, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(10.860109, shape=(), dtype=float32)
# voting :  2 tf.Tensor(10.860109, shape=(), dtype=float32)
# sentence: <start> ¿ donde esta el zoologico ? <end>
# p1 :  90 tf.Tensor(11.514825, shape=(), dtype=float32)
# p2 :  90 tf.Tensor(11.514825, shape=(), dtype=float32)
# p3 :  90 tf.Tensor(11.514825, shape=(), dtype=float32)
# p4 :  90 tf.Tensor(11.514825, shape=(), dtype=float32)
# p5 :  90 tf.Tensor(11.514825, shape=(), dtype=float32)
# voting :  90 tf.Tensor(11.514825, shape=(), dtype=float32)
# p1 :  11 tf.Tensor(9.169952, shape=(), dtype=float32)
# p2 :  15 tf.Tensor(8.982722, shape=(), dtype=float32)
# p3 :  15 tf.Tensor(8.982722, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(9.169952, shape=(), dtype=float32)
# p5 :  15 tf.Tensor(8.982722, shape=(), dtype=float32)
# voting :  11 tf.Tensor(9.169952, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(10.403662, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(10.403662, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(10.403662, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(10.403662, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(10.403662, shape=(), dtype=float32)
# voting :  5 tf.Tensor(10.403662, shape=(), dtype=float32)
# p1 :  1224 tf.Tensor(9.080177, shape=(), dtype=float32)
# p2 :  1224 tf.Tensor(9.080177, shape=(), dtype=float32)
# p3 :  1224 tf.Tensor(9.080177, shape=(), dtype=float32)
# p4 :  1224 tf.Tensor(9.080177, shape=(), dtype=float32)
# p5 :  1224 tf.Tensor(9.080177, shape=(), dtype=float32)
# voting :  1224 tf.Tensor(9.080177, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(8.785848, shape=(), dtype=float32)
# p2 :  10 tf.Tensor(8.785848, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(8.785848, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(8.785848, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(8.785848, shape=(), dtype=float32)
# voting :  10 tf.Tensor(8.785848, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.338652, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.338652, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.338652, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.338652, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.338652, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.338652, shape=(), dtype=float32)
# sentence: <start> el nombre de mi hijo es tom . <end>
# p1 :  25 tf.Tensor(7.7248597, shape=(), dtype=float32)
# p2 :  25 tf.Tensor(7.7248597, shape=(), dtype=float32)
# p3 :  25 tf.Tensor(7.7248597, shape=(), dtype=float32)
# p4 :  25 tf.Tensor(7.7248597, shape=(), dtype=float32)
# p5 :  25 tf.Tensor(7.7248597, shape=(), dtype=float32)
# voting :  25 tf.Tensor(7.7248597, shape=(), dtype=float32)
# p1 :  233 tf.Tensor(6.250506, shape=(), dtype=float32)
# p2 :  165 tf.Tensor(4.5871606, shape=(), dtype=float32)
# p3 :  233 tf.Tensor(6.250506, shape=(), dtype=float32)
# p4 :  366 tf.Tensor(6.6383257, shape=(), dtype=float32)
# p5 :  233 tf.Tensor(6.250506, shape=(), dtype=float32)
# voting :  366 tf.Tensor(6.6383257, shape=(), dtype=float32)
# p1 :  15 tf.Tensor(7.0858335, shape=(), dtype=float32)
# p2 :  15 tf.Tensor(7.0858335, shape=(), dtype=float32)
# p3 :  15 tf.Tensor(7.0858335, shape=(), dtype=float32)
# p4 :  15 tf.Tensor(7.0858335, shape=(), dtype=float32)
# p5 :  18 tf.Tensor(4.316943, shape=(), dtype=float32)
# voting :  15 tf.Tensor(7.0858335, shape=(), dtype=float32)
# p1 :  1284 tf.Tensor(3.3135536, shape=(), dtype=float32)
# p2 :  8 tf.Tensor(4.654685, shape=(), dtype=float32)
# p3 :  176 tf.Tensor(2.25232, shape=(), dtype=float32)
# p4 :  366 tf.Tensor(5.37693, shape=(), dtype=float32)
# p5 :  25 tf.Tensor(4.6640196, shape=(), dtype=float32)
# voting :  366 tf.Tensor(5.37693, shape=(), dtype=float32)
# p1 :  11 tf.Tensor(8.463719, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(8.463719, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(8.463719, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(8.463719, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(8.463719, shape=(), dtype=float32)
# voting :  11 tf.Tensor(8.463719, shape=(), dtype=float32)
# p1 :  8 tf.Tensor(7.8066826, shape=(), dtype=float32)
# p2 :  8 tf.Tensor(7.8066826, shape=(), dtype=float32)
# p3 :  8 tf.Tensor(7.8066826, shape=(), dtype=float32)
# p4 :  8 tf.Tensor(7.8066826, shape=(), dtype=float32)
# p5 :  8 tf.Tensor(7.8066826, shape=(), dtype=float32)
# voting :  8 tf.Tensor(7.8066826, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.370115, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.370115, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.370115, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.370115, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.370115, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.370115, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.523267, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.523267, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.523267, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.523267, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.523267, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.523267, shape=(), dtype=float32)
# sentence: <start> tenemos cosas mas grandes de que preocuparnos . <end>
# p1 :  27 tf.Tensor(8.991072, shape=(), dtype=float32)
# p2 :  27 tf.Tensor(8.991072, shape=(), dtype=float32)
# p3 :  27 tf.Tensor(8.991072, shape=(), dtype=float32)
# p4 :  27 tf.Tensor(8.991072, shape=(), dtype=float32)
# p5 :  27 tf.Tensor(8.991072, shape=(), dtype=float32)
# voting :  27 tf.Tensor(8.991072, shape=(), dtype=float32)
# p1 :  23 tf.Tensor(8.356738, shape=(), dtype=float32)
# p2 :  23 tf.Tensor(8.356738, shape=(), dtype=float32)
# p3 :  23 tf.Tensor(8.356738, shape=(), dtype=float32)
# p4 :  23 tf.Tensor(8.356738, shape=(), dtype=float32)
# p5 :  23 tf.Tensor(8.356738, shape=(), dtype=float32)
# voting :  23 tf.Tensor(8.356738, shape=(), dtype=float32)
# p1 :  93 tf.Tensor(5.1218624, shape=(), dtype=float32)
# p2 :  93 tf.Tensor(5.1218624, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(4.0103426, shape=(), dtype=float32)
# p4 :  106 tf.Tensor(4.978566, shape=(), dtype=float32)
# p5 :  106 tf.Tensor(4.978566, shape=(), dtype=float32)
# voting :  93 tf.Tensor(5.1218624, shape=(), dtype=float32)
# p1 :  451 tf.Tensor(4.9547048, shape=(), dtype=float32)
# p2 :  651 tf.Tensor(4.746125, shape=(), dtype=float32)
# p3 :  651 tf.Tensor(4.746125, shape=(), dtype=float32)
# p4 :  329 tf.Tensor(3.7592921, shape=(), dtype=float32)
# p5 :  270 tf.Tensor(3.929325, shape=(), dtype=float32)
# voting :  451 tf.Tensor(4.9547048, shape=(), dtype=float32)
# p1 :  235 tf.Tensor(4.114587, shape=(), dtype=float32)
# p2 :  6 tf.Tensor(6.0284014, shape=(), dtype=float32)
# p3 :  6 tf.Tensor(6.0284014, shape=(), dtype=float32)
# p4 :  6 tf.Tensor(6.0284014, shape=(), dtype=float32)
# p5 :  95 tf.Tensor(5.379029, shape=(), dtype=float32)
# voting :  6 tf.Tensor(6.0284014, shape=(), dtype=float32)
# p1 :  624 tf.Tensor(6.6945624, shape=(), dtype=float32)
# p2 :  624 tf.Tensor(6.6945624, shape=(), dtype=float32)
# p3 :  624 tf.Tensor(6.6945624, shape=(), dtype=float32)
# p4 :  624 tf.Tensor(6.6945624, shape=(), dtype=float32)
# p5 :  624 tf.Tensor(6.6945624, shape=(), dtype=float32)
# voting :  624 tf.Tensor(6.6945624, shape=(), dtype=float32)
# p1 :  63 tf.Tensor(9.531909, shape=(), dtype=float32)
# p2 :  63 tf.Tensor(9.531909, shape=(), dtype=float32)
# p3 :  63 tf.Tensor(9.531909, shape=(), dtype=float32)
# p4 :  63 tf.Tensor(9.531909, shape=(), dtype=float32)
# p5 :  63 tf.Tensor(9.531909, shape=(), dtype=float32)
# voting :  63 tf.Tensor(9.531909, shape=(), dtype=float32)
# p1 :  29 tf.Tensor(3.1619976, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(6.2663875, shape=(), dtype=float32)
# p3 :  6 tf.Tensor(4.811513, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(6.2663875, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(6.2663875, shape=(), dtype=float32)
# voting :  3 tf.Tensor(6.2663875, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.448603, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.448603, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.448603, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.448603, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.448603, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.448603, shape=(), dtype=float32)
# sentence: <start> juntemonos pasado manana . <end>
# p1 :  88 tf.Tensor(7.7591352, shape=(), dtype=float32)
# p2 :  88 tf.Tensor(7.7591352, shape=(), dtype=float32)
# p3 :  88 tf.Tensor(7.7591352, shape=(), dtype=float32)
# p4 :  88 tf.Tensor(7.7591352, shape=(), dtype=float32)
# p5 :  88 tf.Tensor(7.7591352, shape=(), dtype=float32)
# voting :  88 tf.Tensor(7.7591352, shape=(), dtype=float32)
# p1 :  15 tf.Tensor(8.960531, shape=(), dtype=float32)
# p2 :  15 tf.Tensor(8.960531, shape=(), dtype=float32)
# p3 :  15 tf.Tensor(8.960531, shape=(), dtype=float32)
# p4 :  15 tf.Tensor(8.960531, shape=(), dtype=float32)
# p5 :  15 tf.Tensor(8.960531, shape=(), dtype=float32)
# voting :  15 tf.Tensor(8.960531, shape=(), dtype=float32)
# p1 :  68 tf.Tensor(6.3573103, shape=(), dtype=float32)
# p2 :  68 tf.Tensor(6.3573103, shape=(), dtype=float32)
# p3 :  68 tf.Tensor(6.3573103, shape=(), dtype=float32)
# p4 :  68 tf.Tensor(6.3573103, shape=(), dtype=float32)
# p5 :  68 tf.Tensor(6.3573103, shape=(), dtype=float32)
# voting :  68 tf.Tensor(6.3573103, shape=(), dtype=float32)
# p1 :  6 tf.Tensor(2.9911847, shape=(), dtype=float32)
# p2 :  67 tf.Tensor(4.149268, shape=(), dtype=float32)
# p3 :  326 tf.Tensor(4.9571943, shape=(), dtype=float32)
# p4 :  326 tf.Tensor(4.9571943, shape=(), dtype=float32)
# p5 :  326 tf.Tensor(4.9571943, shape=(), dtype=float32)
# voting :  326 tf.Tensor(4.9571943, shape=(), dtype=float32)
# p1 :  163 tf.Tensor(5.787554, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(4.817739, shape=(), dtype=float32)
# p3 :  163 tf.Tensor(5.787554, shape=(), dtype=float32)
# p4 :  315 tf.Tensor(4.8726287, shape=(), dtype=float32)
# p5 :  9 tf.Tensor(2.356875, shape=(), dtype=float32)
# voting :  163 tf.Tensor(5.787554, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.100447, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.100447, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.100447, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.100447, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.100447, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.100447, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.307768, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.307768, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.307768, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.307768, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.307768, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.307768, shape=(), dtype=float32)
# sentence: <start> ¿ que estas escribiendo ? <end>
# p1 :  29 tf.Tensor(9.281349, shape=(), dtype=float32)
# p2 :  29 tf.Tensor(9.281349, shape=(), dtype=float32)
# p3 :  29 tf.Tensor(9.281349, shape=(), dtype=float32)
# p4 :  29 tf.Tensor(9.281349, shape=(), dtype=float32)
# p5 :  29 tf.Tensor(9.281349, shape=(), dtype=float32)
# voting :  29 tf.Tensor(9.281349, shape=(), dtype=float32)
# p1 :  53 tf.Tensor(8.900347, shape=(), dtype=float32)
# p2 :  53 tf.Tensor(8.900347, shape=(), dtype=float32)
# p3 :  53 tf.Tensor(8.900347, shape=(), dtype=float32)
# p4 :  53 tf.Tensor(8.900347, shape=(), dtype=float32)
# p5 :  53 tf.Tensor(8.900347, shape=(), dtype=float32)
# voting :  53 tf.Tensor(8.900347, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(9.518219, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(9.518219, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(9.518219, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(9.518219, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(9.518219, shape=(), dtype=float32)
# voting :  7 tf.Tensor(9.518219, shape=(), dtype=float32)
# p1 :  254 tf.Tensor(5.316296, shape=(), dtype=float32)
# p2 :  968 tf.Tensor(6.118717, shape=(), dtype=float32)
# p3 :  729 tf.Tensor(0.66847074, shape=(), dtype=float32)
# p4 :  39 tf.Tensor(4.4987774, shape=(), dtype=float32)
# p5 :  66 tf.Tensor(5.273919, shape=(), dtype=float32)
# voting :  968 tf.Tensor(6.118717, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(8.793317, shape=(), dtype=float32)
# p2 :  10 tf.Tensor(8.793317, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(8.793317, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(8.793317, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(8.793317, shape=(), dtype=float32)
# voting :  10 tf.Tensor(8.793317, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.447904, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.447904, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.447904, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.447904, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.447904, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.447904, shape=(), dtype=float32)
# sentence: <start> ¿ este es tu vino ? <end>
# p1 :  11 tf.Tensor(9.89859, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(9.89859, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(9.89859, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(9.89859, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(9.89859, shape=(), dtype=float32)
# voting :  11 tf.Tensor(9.89859, shape=(), dtype=float32)
# p1 :  21 tf.Tensor(10.768311, shape=(), dtype=float32)
# ...
# voting :  414 tf.Tensor(7.037164, shape=(), dtype=float32)
# p1 :  93 tf.Tensor(5.0652666, shape=(), dtype=float32)
# p2 :  455 tf.Tensor(4.899131, shape=(), dtype=float32)
# p3 :  93 tf.Tensor(5.0652666, shape=(), dtype=float32)
# p4 :  93 tf.Tensor(5.0652666, shape=(), dtype=float32)
# p5 :  93 tf.Tensor(5.0652666, shape=(), dtype=float32)
# voting :  93 tf.Tensor(5.0652666, shape=(), dtype=float32)
# p1 :  93 tf.Tensor(4.2441583, shape=(), dtype=float32)
# p2 :  56 tf.Tensor(4.412757, shape=(), dtype=float32)
# p3 :  63 tf.Tensor(2.5647182, shape=(), dtype=float32)
# p4 :  95 tf.Tensor(4.7955713, shape=(), dtype=float32)
# p5 :  56 tf.Tensor(4.412757, shape=(), dtype=float32)
# voting :  95 tf.Tensor(4.7955713, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(2.4324296, shape=(), dtype=float32)
# p2 :  2545 tf.Tensor(1.0511403, shape=(), dtype=float32)
# p3 :  135 tf.Tensor(1.616869, shape=(), dtype=float32)
# p4 :  73 tf.Tensor(3.98508, shape=(), dtype=float32)
# p5 :  9 tf.Tensor(3.2418828, shape=(), dtype=float32)
# voting :  73 tf.Tensor(3.98508, shape=(), dtype=float32)
# p1 :  524 tf.Tensor(9.791435, shape=(), dtype=float32)
# p2 :  524 tf.Tensor(9.791435, shape=(), dtype=float32)
# p3 :  524 tf.Tensor(9.791435, shape=(), dtype=float32)
# p4 :  524 tf.Tensor(9.791435, shape=(), dtype=float32)
# p5 :  524 tf.Tensor(9.791435, shape=(), dtype=float32)
# voting :  524 tf.Tensor(9.791435, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(7.3657274, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(7.3657274, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(7.3657274, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(7.3657274, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(7.3657274, shape=(), dtype=float32)
# voting :  3 tf.Tensor(7.3657274, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.794353, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.794353, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.794353, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.794353, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.794353, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.794353, shape=(), dtype=float32)
# sentence: <start> ¿ podrias darme tu nombre y tu numero de telefono ? <end>
# p1 :  114 tf.Tensor(7.754068, shape=(), dtype=float32)
# p2 :  114 tf.Tensor(7.754068, shape=(), dtype=float32)
# p3 :  114 tf.Tensor(7.754068, shape=(), dtype=float32)
# p4 :  33 tf.Tensor(7.415109, shape=(), dtype=float32)
# p5 :  114 tf.Tensor(7.754068, shape=(), dtype=float32)
# voting :  114 tf.Tensor(7.754068, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(9.811434, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(9.811434, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(9.811434, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(9.811434, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(9.811434, shape=(), dtype=float32)
# voting :  7 tf.Tensor(9.811434, shape=(), dtype=float32)
# p1 :  91 tf.Tensor(7.1088395, shape=(), dtype=float32)
# p2 :  151 tf.Tensor(7.650794, shape=(), dtype=float32)
# p3 :  91 tf.Tensor(7.1088395, shape=(), dtype=float32)
# p4 :  151 tf.Tensor(7.650794, shape=(), dtype=float32)
# p5 :  91 tf.Tensor(7.1088395, shape=(), dtype=float32)
# voting :  151 tf.Tensor(7.650794, shape=(), dtype=float32)
# p1 :  24 tf.Tensor(8.780355, shape=(), dtype=float32)
# p2 :  35 tf.Tensor(7.367961, shape=(), dtype=float32)
# p3 :  24 tf.Tensor(8.780355, shape=(), dtype=float32)
# p4 :  24 tf.Tensor(8.780355, shape=(), dtype=float32)
# p5 :  24 tf.Tensor(8.780355, shape=(), dtype=float32)
# voting :  24 tf.Tensor(8.780355, shape=(), dtype=float32)
# p1 :  35 tf.Tensor(8.27464, shape=(), dtype=float32)
# p2 :  35 tf.Tensor(8.27464, shape=(), dtype=float32)
# p3 :  35 tf.Tensor(8.27464, shape=(), dtype=float32)
# p4 :  35 tf.Tensor(8.27464, shape=(), dtype=float32)
# p5 :  35 tf.Tensor(8.27464, shape=(), dtype=float32)
# voting :  35 tf.Tensor(8.27464, shape=(), dtype=float32)
# p1 :  233 tf.Tensor(8.623655, shape=(), dtype=float32)
# p2 :  233 tf.Tensor(8.623655, shape=(), dtype=float32)
# p3 :  233 tf.Tensor(8.623655, shape=(), dtype=float32)
# p4 :  233 tf.Tensor(8.623655, shape=(), dtype=float32)
# p5 :  233 tf.Tensor(8.623655, shape=(), dtype=float32)
# voting :  233 tf.Tensor(8.623655, shape=(), dtype=float32)
# p1 :  42 tf.Tensor(7.6893525, shape=(), dtype=float32)
# p2 :  42 tf.Tensor(7.6893525, shape=(), dtype=float32)
# p3 :  20 tf.Tensor(5.023465, shape=(), dtype=float32)
# p4 :  42 tf.Tensor(7.6893525, shape=(), dtype=float32)
# p5 :  42 tf.Tensor(7.6893525, shape=(), dtype=float32)
# voting :  42 tf.Tensor(7.6893525, shape=(), dtype=float32)
# p1 :  24 tf.Tensor(3.0687282, shape=(), dtype=float32)
# p2 :  35 tf.Tensor(5.0420475, shape=(), dtype=float32)
# p3 :  35 tf.Tensor(5.0420475, shape=(), dtype=float32)
# p4 :  401 tf.Tensor(3.1415, shape=(), dtype=float32)
# p5 :  35 tf.Tensor(5.0420475, shape=(), dtype=float32)
# voting :  35 tf.Tensor(5.0420475, shape=(), dtype=float32)
# p1 :  662 tf.Tensor(7.098329, shape=(), dtype=float32)
# p2 :  401 tf.Tensor(7.1278396, shape=(), dtype=float32)
# p3 :  401 tf.Tensor(7.1278396, shape=(), dtype=float32)
# p4 :  401 tf.Tensor(7.1278396, shape=(), dtype=float32)
# p5 :  662 tf.Tensor(7.098329, shape=(), dtype=float32)
# voting :  401 tf.Tensor(7.1278396, shape=(), dtype=float32)
# p1 :  469 tf.Tensor(7.560103, shape=(), dtype=float32)
# p2 :  469 tf.Tensor(7.560103, shape=(), dtype=float32)
# p3 :  469 tf.Tensor(7.560103, shape=(), dtype=float32)
# p4 :  469 tf.Tensor(7.560103, shape=(), dtype=float32)
# p5 :  469 tf.Tensor(7.560103, shape=(), dtype=float32)
# voting :  469 tf.Tensor(7.560103, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(8.001811, shape=(), dtype=float32)
# p2 :  10 tf.Tensor(8.001811, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(8.001811, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(8.001811, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(8.001811, shape=(), dtype=float32)
# voting :  10 tf.Tensor(8.001811, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.023264, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.023264, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.023264, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.023264, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.023264, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.023264, shape=(), dtype=float32)
# sentence: <start> los documentos secretos fueron triturados . <end>
# no words!
# sentence: <start> tom esta en una racha de suerte . <end>
# p1 :  8 tf.Tensor(10.309306, shape=(), dtype=float32)
# p2 :  8 tf.Tensor(10.309306, shape=(), dtype=float32)
# p3 :  8 tf.Tensor(10.309306, shape=(), dtype=float32)
# p4 :  8 tf.Tensor(10.309306, shape=(), dtype=float32)
# p5 :  8 tf.Tensor(10.309306, shape=(), dtype=float32)
# voting :  8 tf.Tensor(10.309306, shape=(), dtype=float32)
# p1 :  11 tf.Tensor(9.565769, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(9.565769, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(9.565769, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(9.565769, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(9.565769, shape=(), dtype=float32)
# voting :  11 tf.Tensor(9.565769, shape=(), dtype=float32)
# p1 :  16 tf.Tensor(7.8356323, shape=(), dtype=float32)
# p2 :  36 tf.Tensor(7.5655046, shape=(), dtype=float32)
# p3 :  16 tf.Tensor(7.8356323, shape=(), dtype=float32)
# p4 :  16 tf.Tensor(7.8356323, shape=(), dtype=float32)
# p5 :  36 tf.Tensor(7.5655046, shape=(), dtype=float32)
# voting :  16 tf.Tensor(7.8356323, shape=(), dtype=float32)
# p1 :  9 tf.Tensor(6.825452, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(6.825452, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(6.825452, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(6.825452, shape=(), dtype=float32)
# p5 :  9 tf.Tensor(6.825452, shape=(), dtype=float32)
# voting :  9 tf.Tensor(6.825452, shape=(), dtype=float32)
# p1 :  902 tf.Tensor(0.8095807, shape=(), dtype=float32)
# p2 :  1401 tf.Tensor(6.3377934, shape=(), dtype=float32)
# p3 :  1401 tf.Tensor(6.3377934, shape=(), dtype=float32)
# p4 :  1401 tf.Tensor(6.3377934, shape=(), dtype=float32)
# p5 :  1401 tf.Tensor(6.3377934, shape=(), dtype=float32)
# voting :  1401 tf.Tensor(6.3377934, shape=(), dtype=float32)
# p1 :  4406 tf.Tensor(8.982848, shape=(), dtype=float32)
# p2 :  4406 tf.Tensor(8.982848, shape=(), dtype=float32)
# p3 :  4406 tf.Tensor(8.982848, shape=(), dtype=float32)
# p4 :  4406 tf.Tensor(8.982848, shape=(), dtype=float32)
# p5 :  4406 tf.Tensor(8.982848, shape=(), dtype=float32)
# voting :  4406 tf.Tensor(8.982848, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(11.029543, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(11.029543, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(11.029543, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(11.029543, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(11.029543, shape=(), dtype=float32)
# voting :  3 tf.Tensor(11.029543, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.130196, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.130196, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.130196, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.130196, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.130196, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.130196, shape=(), dtype=float32)
# sentence: <start> el enemigo mas terrible es un amigo pasado . <end>
# p1 :  5 tf.Tensor(8.071068, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(8.071068, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(8.071068, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(8.071068, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(8.071068, shape=(), dtype=float32)
# voting :  5 tf.Tensor(8.071068, shape=(), dtype=float32)
# p1 :  1065 tf.Tensor(7.2011733, shape=(), dtype=float32)
# p2 :  1065 tf.Tensor(7.2011733, shape=(), dtype=float32)
# p3 :  1065 tf.Tensor(7.2011733, shape=(), dtype=float32)
# p4 :  820 tf.Tensor(3.2941098, shape=(), dtype=float32)
# p5 :  3540 tf.Tensor(0.22672263, shape=(), dtype=float32)
# voting :  1065 tf.Tensor(7.2011733, shape=(), dtype=float32)
# p1 :  1039 tf.Tensor(1.6122978, shape=(), dtype=float32)
# p2 :  497 tf.Tensor(2.668774, shape=(), dtype=float32)
# p3 :  93 tf.Tensor(3.9933045, shape=(), dtype=float32)
# p4 :  93 tf.Tensor(3.9933045, shape=(), dtype=float32)
# p5 :  93 tf.Tensor(3.9933045, shape=(), dtype=float32)
# voting :  93 tf.Tensor(3.9933045, shape=(), dtype=float32)
# p1 :  270 tf.Tensor(4.289399, shape=(), dtype=float32)
# p2 :  800 tf.Tensor(5.189664, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(3.9659474, shape=(), dtype=float32)
# p4 :  800 tf.Tensor(5.189664, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(3.9659474, shape=(), dtype=float32)
# voting :  800 tf.Tensor(5.189664, shape=(), dtype=float32)
# p1 :  11 tf.Tensor(7.03526, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(7.03526, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(7.03526, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(7.03526, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(7.03526, shape=(), dtype=float32)
# voting :  11 tf.Tensor(7.03526, shape=(), dtype=float32)
# p1 :  9 tf.Tensor(6.8982973, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(6.8982973, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(6.8982973, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(6.8982973, shape=(), dtype=float32)
# p5 :  9 tf.Tensor(6.8982973, shape=(), dtype=float32)
# voting :  9 tf.Tensor(6.8982973, shape=(), dtype=float32)
# p1 :  214 tf.Tensor(9.047258, shape=(), dtype=float32)
# p2 :  214 tf.Tensor(9.047258, shape=(), dtype=float32)
# p3 :  323 tf.Tensor(2.130933, shape=(), dtype=float32)
# p4 :  214 tf.Tensor(9.047258, shape=(), dtype=float32)
# p5 :  214 tf.Tensor(9.047258, shape=(), dtype=float32)
# voting :  214 tf.Tensor(9.047258, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(4.9928536, shape=(), dtype=float32)
# p2 :  18 tf.Tensor(5.9674864, shape=(), dtype=float32)
# p3 :  15 tf.Tensor(3.0392272, shape=(), dtype=float32)
# p4 :  18 tf.Tensor(5.9674864, shape=(), dtype=float32)
# p5 :  18 tf.Tensor(5.9674864, shape=(), dtype=float32)
# voting :  18 tf.Tensor(5.9674864, shape=(), dtype=float32)
# p1 :  9 tf.Tensor(4.837963, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(4.0688925, shape=(), dtype=float32)
# p3 :  376 tf.Tensor(0.73268396, shape=(), dtype=float32)
# p4 :  324 tf.Tensor(4.7210684, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(4.0688925, shape=(), dtype=float32)
# voting :  9 tf.Tensor(4.837963, shape=(), dtype=float32)
# p1 :  214 tf.Tensor(5.2375283, shape=(), dtype=float32)
# p2 :  165 tf.Tensor(3.8290894, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(2.5822058, shape=(), dtype=float32)
# p4 :  214 tf.Tensor(5.2375283, shape=(), dtype=float32)
# p5 :  214 tf.Tensor(5.2375283, shape=(), dtype=float32)
# voting :  214 tf.Tensor(5.2375283, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(6.804947, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(6.804947, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(6.804947, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(6.804947, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(6.804947, shape=(), dtype=float32)
# voting :  3 tf.Tensor(6.804947, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.970145, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.970145, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.970145, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.970145, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.970145, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.970145, shape=(), dtype=float32)
# sentence: <start> tom es un conductor muy precavido . <end>
# p1 :  8 tf.Tensor(10.131628, shape=(), dtype=float32)
# p2 :  8 tf.Tensor(10.131628, shape=(), dtype=float32)
# p3 :  8 tf.Tensor(10.131628, shape=(), dtype=float32)
# p4 :  8 tf.Tensor(10.131628, shape=(), dtype=float32)
# p5 :  8 tf.Tensor(10.131628, shape=(), dtype=float32)
# voting :  8 tf.Tensor(10.131628, shape=(), dtype=float32)
# p1 :  11 tf.Tensor(9.812694, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(9.812694, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(9.812694, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(9.812694, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(9.812694, shape=(), dtype=float32)
# voting :  11 tf.Tensor(9.812694, shape=(), dtype=float32)
# p1 :  9 tf.Tensor(9.794268, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(9.794268, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(9.794268, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(9.794268, shape=(), dtype=float32)
# p5 :  9 tf.Tensor(9.794268, shape=(), dtype=float32)
# voting :  9 tf.Tensor(9.794268, shape=(), dtype=float32)
# p1 :  58 tf.Tensor(5.722561, shape=(), dtype=float32)
# p2 :  58 tf.Tensor(5.722561, shape=(), dtype=float32)
# p3 :  58 tf.Tensor(5.722561, shape=(), dtype=float32)
# p4 :  165 tf.Tensor(3.5431876, shape=(), dtype=float32)
# p5 :  58 tf.Tensor(5.722561, shape=(), dtype=float32)
# voting :  58 tf.Tensor(5.722561, shape=(), dtype=float32)
# p1 :  8742 tf.Tensor(4.2639513, shape=(), dtype=float32)
# p2 :  4895 tf.Tensor(3.9396603, shape=(), dtype=float32)
# p3 :  1630 tf.Tensor(3.0596929, shape=(), dtype=float32)
# p4 :  1732 tf.Tensor(4.875675, shape=(), dtype=float32)
# p5 :  9340 tf.Tensor(3.284032, shape=(), dtype=float32)
# voting :  1732 tf.Tensor(4.875675, shape=(), dtype=float32)
# p1 :  18 tf.Tensor(6.2439284, shape=(), dtype=float32)
# p2 :  18 tf.Tensor(6.2439284, shape=(), dtype=float32)
# p3 :  18 tf.Tensor(6.2439284, shape=(), dtype=float32)
# p4 :  758 tf.Tensor(5.3630133, shape=(), dtype=float32)
# p5 :  18 tf.Tensor(6.2439284, shape=(), dtype=float32)
# voting :  18 tf.Tensor(6.2439284, shape=(), dtype=float32)
# p1 :  1939 tf.Tensor(3.3856797, shape=(), dtype=float32)
# p2 :  2184 tf.Tensor(4.892428, shape=(), dtype=float32)
# p3 :  3968 tf.Tensor(-0.23546275, shape=(), dtype=float32)
# p4 :  1562 tf.Tensor(4.776183, shape=(), dtype=float32)
# p5 :  3301 tf.Tensor(2.4802547, shape=(), dtype=float32)
# voting :  2184 tf.Tensor(4.892428, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(10.327759, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(10.327759, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(10.327759, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(10.327759, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(10.327759, shape=(), dtype=float32)
# voting :  3 tf.Tensor(10.327759, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(13.286461, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(13.286461, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(13.286461, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(13.286461, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(13.286461, shape=(), dtype=float32)
# voting :  2 tf.Tensor(13.286461, shape=(), dtype=float32)

# %% [markdown]
# ### 긴 문장 번역 Test ###
#
# Le preguntó qué estaba pasando, pero ella no dijo nada.
#
# He asked her what was going on, but she didn't say anything.

# %%
# long_test = u'Le preguntó qué estaba pasando, pero ella no dijo nada.'
# translate(long_test)

# %% [markdown]
# ### 더 긴 문장 번역 Test ###
#
# Si quieres sonar como un hablante nativo, debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un músico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado.
#
# If you want to sound like a native speaker, you must be willing toq practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo.

# %%
# long_test2 = u'Si quieres sonar como un hablante nativo, debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un músico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado.'

# translate(long_test)
