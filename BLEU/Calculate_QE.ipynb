# %%
import torch
import openpyxl
import numpy as np
from tqe import TQE

# %%
wb = openpyxl.load_workbook('BLEU_Score.xlsx')
sheet = wb['Ensemble BLEU']
# source : 번역 원문
# target : 기계 번역 문장

for i in range(2, 1002):
    target = []
    source = []
    candidate = sheet.cell(row = i, column = 4).value.capitalize()
    reference = sheet.cell(row = i, column = 3).value
    print(i, ':', candidate)

    # Translation Quality Estimator (QE)
    # https://github.com/theRay07/Translation-Quality-Estimator
    target.append(candidate)
    source.append(reference)
    model = TQE('LaBSE')
    cos_sim_values = model.fit(source, target)
    sheet.cell(row = i, column = 9).value = cos_sim_values[0]
    
wb.save('BLEU_Score.xlsx')

# # lang_1 = ["what are you doing", "what is your name"]
# # lang_2 = ["तुम क्या कर रहे हो", "तुम्हारा नाम क्या है"]
# lang_1 = ["what are you doing here"]
# lang_2 = ["तुम यहां क्या कर रहे होो"]

# # lang_1 = ["they were not there .", "i never work with him ."]
# # lang_2 = ["Ellos no estaban allá.", "Jamás trabajé con él."]

# model = TQE('LaBSE')
# cos_sim_values = model.fit(lang_1, lang_2)
# print(cos_sim_values)
# Out:
# 2 : You told you what happened , did you ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 3 : They were not there .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 4 : I don t like both of boys .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 5 : I never work with him .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 6 : My father does rice .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 7 : Tell me what you did in advance .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 8 : How many of you should write ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 9 : How do you go on my house ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 10 : My mother bakes bread every morning .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 11 : I ve made the reading this novel .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 12 : He was standing at the corner .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 13 : The politician didn t seem to be nervous when they re on the court .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 14 : Where is the zoo ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 15 : My son s son is tom .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 16 : We have more important to worry about .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 17 : Let s get together tomorrow .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 18 : What re you writing ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 19 : Is this your wine ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 20 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 21 : I thought tom would want to help me .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 22 : What do you want to give tom ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 23 : I don t want to allow that .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 24 : There s no other customers .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 25 : Are you coming to visit me ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 26 : I assume you re here to ask tom for tom .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 27 : Tom appreciated mary s kindness .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 28 : Where is the other ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 29 : The poor in the men are not always appreciated .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 30 : As soon as you know , the fact , you know , the fact , the world is the key .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 31 : Tom chased the tv on tv .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 32 : I like the dog .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 33 : It s something i have to do .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 34 : Tom wasn t very good to read in the dozen .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 35 : Could you come over here ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 36 : That s lucky you won t last forever .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 37 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 38 : I thought tom had left mary a month .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 39 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 40 : The power is on .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 41 : It s cruel to a blind .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 42 : What a wonderful present !
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 43 : Tom is not a job .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 44 : The city was getting into the fog .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 45 : Do you know how to use this ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 46 : Tom ate more than an hour .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 47 : Could you give me your name and your phone number ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 48 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 49 : Tom is in a winning streak .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 50 : The enemy more terrible is a friend of a friend .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 51 : Tom is a very capable of scenery .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 52 : I ll be my house .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 53 : Tom is a little cold .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 54 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 55 : How foolish of you !
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 56 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 57 : You d better start .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 58 : What is tom popular ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 59 : I don t know why he gave the company .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 60 : Please let me go .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 61 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 62 : I m want to talk to tom .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
#

# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 172 : Was there any more in the bar ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 173 : I went to see the baseball game yesterday .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 174 : I know how to know as you .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 175 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 176 : Two has been weeks and i ve seen .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 177 : Keep the best for the end .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 178 : We set the christmas present at the tree .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 179 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 180 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 181 : Tell me the truth .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 182 : Take this medicine before each meal .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 183 : My little brother all day every summer .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 184 : Why is she so popular ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 185 : Please give me a piece of paper to write , please .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 186 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 187 : I didn t know you to drive .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 188 : Almost all girls are very .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 189 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 190 : I don t think tom will come back .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 191 : Tom , what do you want to dinner ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 192 : About the year .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 193 : It used to be a english colony .
# Computing embeddings for strings in list 1
# ...
# Computing cosine similarity scores
# 939 : What can you do for me ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 940 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 941 : How do you know that ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 942 : Read these instructions .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 943 : A nice person to open the box .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 944 : Tomorrow , tomorrow .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 945 : Money isn t everything , but you don t have nothing .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 946 : What do you advise me to do ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 947 : You shouldn t use your clothes if you are pregnant .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 948 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 949 : She lived there for many years .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 950 : He is not the most kind of the class .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 951 : This is not the last time .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 952 : He just bought a car car .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 953 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 954 : I can t believe tom won t come .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 955 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 956 : The millionaire had the intention of the masterpiece no matter what it cost .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 957 : I ll give you everything you need .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 958 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 959 : He has betrayed his friends for money .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 960 : Let s have a baby .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 961 : Tom seems worried .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 962 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 963 : He is often be snobbish .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 964 : Tom has a strong cold .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 965 : Tom has no time to help you .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 966 : I d like some fun .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 967 : I couldn t have expressed myself better .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 968 : Why are you so sure tom is canadian ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 969 : The teacher read a narrow escape from the class .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 970 : Tom was hurt .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 971 : You are in smoke here .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 972 : I want to be with you on you .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 973 : All looked at the window .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 974 : I couldn t give up another .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 975 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 976 : What s your favorite food ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 977 : The temperature fell down .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 978 : I didn t go anywhere because you told me not to .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 979 : Tom claimed to be son mary s son .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 980 : The cables will pay the electricity .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 981 : He turned his request of a day off .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 982 : Please could you sign this document ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 983 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 984 : I take off every day .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 985 : He came out of the room .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 986 : Was tom here when it happened ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 987 : I spent the whole afternoon trying to find my keys .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 988 : I just wanted to tell you that i ve met tom this morning .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 989 : Do you think it s right ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 990 : Call my husband !
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 991 : He was in a good mood .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 992 : I feel like going out of going out of home .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 993 : The answer is not the answer .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 994 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 995 : Tom will come back soon .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 996 : This house needs a picture of painting .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 997 : My father is busy with me .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 998 : See you tomorrow in the library .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 999 : He let me waiting for me .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 1000 : The teacher treated her as one of his students .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 1001 : Do you have alcohol free drinks ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores

# %%
wb = openpyxl.load_workbook('BLEU_Score.xlsx')
sheet = wb['Ensemble BLEU']
qe = []


for i in range(2, 1002):
    qe.append(float(sheet.cell(row = i, column = 9).value))

    
qe = np.array(qe)

sheet.cell(row = 1002, column = 9).value = qe.mean()


wb.save('BLEU_Score.xlsx')
