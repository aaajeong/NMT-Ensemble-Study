# %%
import torch
import openpyxl
import numpy as np
from tqe import TQE

# %%
wb = openpyxl.load_workbook('BLEU_Score.xlsx')
sheet = wb['Ensemble BLEU']
# source : 번역 원문
# target : 기계 번역 문장

for i in range(2, 1002):
    target = []
    source = []
    candidate = sheet.cell(row = i, column = 4).value.capitalize()
    reference = sheet.cell(row = i, column = 3).value
    print(i, ':', candidate)

    # Translation Quality Estimator (QE)
    # https://github.com/theRay07/Translation-Quality-Estimator
    target.append(candidate)
    source.append(reference)
    model = TQE('LaBSE')
    cos_sim_values = model.fit(source, target)
    sheet.cell(row = i, column = 9).value = cos_sim_values[0]
    
wb.save('BLEU_Score.xlsx')

# # lang_1 = ["what are you doing", "what is your name"]
# # lang_2 = ["तुम क्या कर रहे हो", "तुम्हारा नाम क्या है"]
# lang_1 = ["what are you doing here"]
# lang_2 = ["तुम यहां क्या कर रहे होो"]

# # lang_1 = ["they were not there .", "i never work with him ."]
# # lang_2 = ["Ellos no estaban allá.", "Jamás trabajé con él."]

# model = TQE('LaBSE')
# cos_sim_values = model.fit(lang_1, lang_2)
# print(cos_sim_values)
# Out:
# 2 : You told you what happened , isn t it
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 3 : They were not there .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 4 : I don t like any boys .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 5 : I never work with him .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 6 : My father manages rice .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 7 : Tell me what you did in advance
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 8 : How many words should i like ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 9 : How did you go on my house ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 10 : My mother bakes bread all morning .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 11 : I ve made the book this
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 12 : He was standing at the corner .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 13 : The post didn t seem mad when we re still .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 14 : Where is the zoo ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 15 : My name is my brother is .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 16 : We have more important things to worry .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 17 : Let s get to pick up tomorrow
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 18 : What re you looking for ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 19 : Is this your wine ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 20 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 21 : I thought tom would want me .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 22 : What do you want to give it ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 23 : I don t want to think that happen .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 24 : There s no use of paper .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 25 : Are you coming , visit me ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 26 : I assume you re here for ask for tom for
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 27 : Tom appreciated mary his kindness
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 28 : Where is the other one ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 29 : The poor war is always honest .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 30 : Most of hobbies , you know , but you re the key
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 31 : Tom crouched beside the tv .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 32 : I like the dog .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 33 : It s something i have to do .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 34 : Tom wasn t very good to read in mind .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 35 : Could you come too ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 36 : That boat is not to get out .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 37 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 38 : I thought tom had left mary a month .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 39 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 40 : The treaty is on .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 41 : It s cruel .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 42 : What a wonderful gift !
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 43 : Tom still have no work ,
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 44 : The city was made in a lot .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 45 : Do you know how to use this ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 46 : Tom ate more more minutes or an hour
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 47 : Could you please lend me your name and me where you
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 48 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 49 : Tom is in a hundred dollars .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 50 : The enemy smell is a friend .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 51 : Tom is a very vivid crime .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 52 : I ll be my house .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 53 : Tom is a little cold .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 54 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 55 : How foolish !
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 56 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 57 : You d better start right now
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 58 : What is tom popular ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 59 : I don t know why he gave the company .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 60 : Please let me go
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
#

# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 168 : I don t know either .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 169 : No one listened to me .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 170 : Those are our country .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 171 : She promised to wake me immediately .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 172 : Would you teach any more in the river
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 173 : I went to see the game of baseball
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 174 : I know as a fool of yourself .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 175 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 176 : Two has been three and i have seen
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 177 : Let s try to the same thing .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 178 : We set the cd out of the wall .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 179 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 180 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 181 : Let me know the truth .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 182 : Take this medicine before you .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 183 : My younger brother every day every morning .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 184 : Why is she so popular ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 185 : Please give me a meal for a lot of bus ,
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 186 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 187 : I didn t know you knew how to drive
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 188 : Almost all human girls are both .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 189 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 190 : I don t think tom will come back .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 191 : Tom , what do you want to call
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 192 : In spite of the forest
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 193 : I used to be a japanese doll .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 194 : How was tom s party ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# ...
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 939 : What can you do for me ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 940 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 941 : How do you know it ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 942 : Read these sentences .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 943 : A new office by bus .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 944 : I ll go tomorrow
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 945 : Money isn t everything , but you can t buy money .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 946 : What do you advise me to do ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 947 : You shouldn t use your clothes . however ,
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 948 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 949 : She lived there for many years .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 950 : He is not the happiest person in the class
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 951 : This will not be the last time .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 952 : He has to buy a car .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 953 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 954 : I can t believe tom doesn t come .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 955 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 956 : The millionaire had intended to swim across the hog .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 957 : I ll give him everything you need .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 958 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 959 : He has helped his friends for money .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 960 : Let s got a baby .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 961 : Tom seems worried .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 962 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 963 : He often natural talent .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 964 : Tom has a strong cold .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 965 : Tom doesn t have time to help you .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 966 : I d like some more cheese .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 967 : I couldn t have studied extra better .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 968 : Why are you so i think tom is canadian ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 969 : The teacher read the bottom of the class .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 970 : Tom was hurt .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 971 : You are under this here .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 972 : I want to be with you before you arrived .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 973 : All looked down the window .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 974 : I couldn t get any bruises .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 975 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 976 : What s your favorite coffee ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 977 : The temperature fell down .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 978 : I didn t go anywhere because you told me not to do it
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 979 : Tom claimed to be son s son .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 980 : The settlers mistakes the music
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 981 : He rejected his application one day .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 982 : Please if i could you this book
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 983 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 984 : I take off every day .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 985 : He came from the room .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 986 : Was tom here when i get ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 987 : I spent the whole afternoon chatting .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 988 : I just wanted to tell you that i ve found it this morning .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 989 : Do you think it s right ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 990 : Call my husband !
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 991 : He was kind of a thing .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 992 : I feel like going out of slippers .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 993 : Tell me the answer .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 994 : No word
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 995 : Tom will come back early .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 996 : This house is a birthday student .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 997 : My father is busy writing .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 998 : See you tomorrow in the library .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 999 : He left me to me .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 1000 : The teacher pointed her like a little girl .
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores
# 1001 : Do you have alcohol a rush ?
# Computing embeddings for strings in list 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing embeddings for strings in list 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Computing cosine similarity scores

# %%
wb = openpyxl.load_workbook('BLEU_Score.xlsx')
sheet = wb['Model 1 BLEU']
qe = []


for i in range(2, 1002):
    qe.append(float(sheet.cell(row = i, column = 9).value))

    
qe = np.array(qe)

sheet.cell(row = 1002, column = 9).value = qe.mean()


wb.save('BLEU_Score.xlsx')
