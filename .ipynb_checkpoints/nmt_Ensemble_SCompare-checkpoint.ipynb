# %% [markdown]
# # **Attention Ensemble  - Soft Voting**
# ---

# %% [markdown]
# ### **Import Libraries**

# %%
import tensorflow as tf
from keras.models import Model
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split 

import unicodedata
import re
import numpy as np
import os
import io
import time
import random
import openpyxl

# %% [markdown]
# ### **데이터 로드**

# %%
path_to_file = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/spa-eng/spa.txt'
path_to_file_esb = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/spa-eng/spa_for_esb.txt'

# %% [markdown]
# ### **데이터 랜덤 셔플**
#
#
# *   [영어, 스페인어] 쌍 shuffle file 새로 저장
# *   번역 테스트 시 주석 처리

# %%
# lines = io.open(path_to_file, encoding='UTF-8').read().strip().split('\n')
# random.shuffle(lines)
# f = open(path_to_file_esb, 'w')
# for i in lines:
#     data = i + '\n'
#     f.write(data)
# f.close()

# %% [markdown]
# ### **데이터(문장) 전처리**

# %%
# 유니코드 파일을 아스키 코드 파일로 변환합니다.
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # 단어와 단어 뒤에 오는 구두점(.)사이에 공백을 생성합니다.
  # 예시: "he is a boy." => "he is a boy ."
  # 참고:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # (a-z, A-Z, ".", "?", "!", ",")을 제외한 모든 것을 공백으로 대체합니다.
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # 모델이 예측을 시작하거나 중단할 때를 알게 하기 위해서
  # 문장에 start와 end 토큰을 추가합니다.
  w = '<start> ' + w + ' <end>'
  return w

# %% [markdown]
# ### **Dataset 생성**
# 1. 문장에 있는 억양을 제거합니다.
# 2. 불필요한 문자를 제거하여 문장을 정리합니다.
# 3. 다음과 같은 형식으로 문장의 쌍을 반환합니다: [영어, 스페인어]

# %%
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %% [markdown]
# ### **Language 가 들어오면 공백 단위로 토큰화**
# - fit_on_texts(): 문자 데이터를 입력받아서 리스트의 형태로 변환
# - texts_to_sequences: 텍스트 안의 단어들을 숫자 시퀀스로 출력
# - pad_sequcences(tensor, padding='post') : 서로 다른 개수의 단어로 이루어진 문장을 같은 길이로 만들어주기 위해 패딩을 사용
#   - padding = 'post' : [[ 0  0  0  5  3  2  4], [ 0  0  0  5  3  2  7],...,]
#   - padding = 'pre' : 뒤 부터 패딩이 채워짐
#   - 가장 긴 sequence 의 길이 만큼

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %% [markdown]
# ### **전처리된 타겟 문장과 입력 문장 쌍을 생성**
# - input_tensor : input 문장의 패딩 처리된 숫자 시퀀스
# - inp_lang_tokenizer : input 문장을 공백 단위로 토큰화, 문자 -> 리스트 변환
# - target_tensor, targ_lang_tokenizer : 위와 비슷

# %%
def load_dataset(path, num_examples=None):
  
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### **언어 데이터셋 크기 제한**
# - 언어 데이터셋을 아래의 크기로 제한하여 훈련과 검증을 수행
# - inp_lang, targ_lang : 인풋,타겟 문장의 문자 -> 리스트 변환 결과
# - max_length_targ, max_length_inp : 인풋, 타겟 문장의 '패딩된' 숫자 시퀀스 길이 -> 타겟 텐서와 입력 텐서의 최대 길이

# %%
# num_examples = 30000
num_examples = 60000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file_esb, num_examples)

max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %% [markdown]
# ### **데이터셋 (테스트 & 검증) 분리**

# %%
# 훈련 집합과 검증 집합을 80대 20으로 분리합니다.
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# 훈련 집합과 검증 집합의 데이터 크기를 출력합니다.
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 48000 48000 12000 12000

# %% [markdown]
# ### 인덱스 -> 해당 word 로
#
# ```
# Input Language; index to word mapping
# 1 ----> <start>
# 93 ----> tomas
# 27 ----> le
# 1063 ----> escribio
# 7 ----> a
# 120 ----> maria
# 3 ----> .
# 2 ----> <end>
# ```
#
#
# ```
# Target Language; index to word mapping
# 1 ----> <start>
# 8 ----> tom
# 695 ----> wrote
# 6 ----> to
# 31 ----> mary
# 3 ----> .
# 2 ----> <end>
# ```

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %% [markdown]
# ### **Buffer, Batch, epoch, embedding dimension, units 설정**
# - Tokenizer 의 word_index 속성 : 속성은 단어와 숫자의 키-값 쌍을 포함하는 딕셔너리를 반환
# - 따라서 vocab_inp_size, vocab_inp_size : 인풋, 타겟의 단어-숫자 딕셔너리 최대 길이 + 1 (?)
# - dataset.batch(BATCH_SIZE, drop_remainder = True) : 배치사이즈 만큼 분할 후 남은 데이터를 drop 할 것인지 여부
# - shuffle : 데이터셋 적절히 섞어준다.

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

# 훈련 집합에서만 shuffle, batch
dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 53]), TensorShape([64, 51]))

# %% [markdown]
# ### **Encoder**
#
#
# 1.   초기화 : vocab_size(단어의 크기), embedding_dim(임베딩 차원 수), enc_units(인코더의 히든 사이즈), batch_sz(배치 사이즈)
#   - embedding_dim : 단어 -> 임베딩 벡터로 하기 위한 차원 수
# 2.  call : gru 에 들어가 output, state 출력
# 3.  initialize_hidden_state : 맨 처음 gru에 들어가기 위한 더미 입력 값

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %% [markdown]
# ### **Encoder 객체 생성**

# %%
# encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **Attention**

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # 쿼리 은닉 상태(query hidden state)는 (batch_size, hidden size)쌍으로 이루어져 있습니다.
    # query_with_time_axis은 (batch_size, 1, hidden size)쌍으로 이루어져 있습니다.
    # values는 (batch_size, max_len, hidden size)쌍으로 이루어져 있습니다.
    # 스코어(score)계산을 위해 덧셈을 수행하고자 시간 축을 확장하여 아래의 과정을 수행합니다.
    query_with_time_axis = tf.expand_dims(query, 1)

    # score는 (batch_size, max_length, 1)쌍으로 이루어져 있습니다.
    # score를 self.V에 적용하기 때문에 마지막 축에 1을 얻습니다.
    # self.V에 적용하기 전에 텐서는 (batch_size, max_length, units)쌍으로 이루어져 있습니다.
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights는 (batch_size, max_length, 1)쌍으로 이루어져 있습니다. 
    attention_weights = tf.nn.softmax(score, axis=1)

    # 덧셈이후 컨텍스트 벡터(context_vector)는 (batch_size, hidden_size)쌍으로 이루어져 있습니다.
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %% [markdown]
# ### **Decoder**
#
#
# 1.   초기화 : vocab_size(단어의 크기), embedding_dim(임베딩 차원 수), enc_units(인코더의 히든 사이즈), batch_sz(배치 사이즈)
# 2.   encoder 와의 차이점 : 마지막 fully_connected_layer(tf.keras.layers.Dense) 추가

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # 어텐션을 사용합니다.
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output는 (batch_size, max_length, hidden_size)쌍으로 이루어져 있습니다.
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # 임베딩층을 통과한 후 x는 (batch_size, 1, embedding_dim)쌍으로 이루어져 있습니다.
    x = self.embedding(x)

    # 컨텍스트 벡터와 임베딩 결과를 결합한 이후 x의 형태는 (batch_size, 1, embedding_dim + hidden_size)쌍으로 이루어져 있습니다.
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # 위에서 결합된 벡터를 GRU에 전달합니다.
    output, state = self.gru(x)

    # output은 (batch_size * 1, hidden_size)쌍으로 이루어져 있습니다.
    output = tf.reshape(output, (-1, output.shape[2]))

    # output은 (batch_size, vocab)쌍으로 이루어져 있습니다.
    x = self.fc(output)

    # return x, state, attention_weights
    return x, state

# %% [markdown]
# ### **Decoder 객체 생성**

# %%
# decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **NMT Model 생성**

# %%
class NMT_Model():
  def __init__(self):
    super(NMT_Model, self).__init__()
    self.encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
    self.decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **Ensemble Model 생성**

# %%
models = []
num_models = 5
for m in range(num_models):
  m = NMT_Model()
  models.append(m)

# %% [markdown]
# ### **Loss Function & Optimizer**

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ### **Chekcpoint**
# - 여기서 학습한 매개변수를 저장, optimizer/encoder/decoder

# %%
checkpoint_dir = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/training_checkpoints_esb'
checkpoint_dir_test = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/training_checkpoints_esb2'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoints = []

for m in range(num_models):
  checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=models[m].encoder,
                                 decoder=models[m].decoder)
  checkpoints.append(checkpoint)

# %%
print(checkpoints)
# Out:
# [<tensorflow.python.training.tracking.util.Checkpoint object at 0x7ffb748cf7f0>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7ffb74a454a8>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7ffb74ae1a20>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7ffb74ae13c8>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7ffb74ae1b00>]

# %% [markdown]
# ### **Train_step**

# %%
# @tf.function
def train_step(model, inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = model.encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # 교사 강요(teacher forcing) - 다음 입력으로 타겟을 피딩(feeding)합니다.
    for t in range(1, targ.shape[1]):
      # enc_output를 디코더에 전달합니다.
      predictions, dec_hidden = model.decoder(dec_input, dec_hidden, enc_output)
      # print('predictions', predictions.shape)

      loss += loss_function(targ[:, t], predictions)

      # 교사 강요(teacher forcing)를 사용합니다. -> 훈련에서는 실제 값을 이용
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))
  variables = model.encoder.trainable_variables + model.decoder.trainable_variables
  gradients = tape.gradient(loss, variables)
  optimizer.apply_gradients(zip(gradients, variables))
  return batch_loss

# %% [markdown]
# ### **학습**
# - 학습 코드 X

# %% [markdown]
# ### **문장 번역(스페인 -> 영어)**
#
# *   tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen='', padding='post') : 일정한 길이(maxlen)로 맞춰준다. (패딩은 뒤에서)
# *
#
#   ```
#   inp_lang.word_index :  {'<start>': 1, '<end>': 2, '.': 3, 'tom': 4, '?': 5...}
#   ```
#
# * tf.expand_dims: 차원을 늘려준다.

# %%
def evaluate(sentence):

  sentence = preprocess_sentence(sentence)

  # 문장, input 딕셔너리 출력 
  print ('sentence:', sentence)

  no_word = 'no word'
  inputs = []
  inputs2 = []
  inputs3 = []
  inputs4 = []
  inputs5 = [] 
    
  for i in sentence.split(' '):
    if i in inp_lang.word_index:
        inputs.append(inp_lang.word_index[i])
        inputs2.append(inp_lang.word_index[i])
        inputs3.append(inp_lang.word_index[i])
        inputs4.append(inp_lang.word_index[i])
        inputs5.append(inp_lang.word_index[i])
    else:
        print('no words!')
        return no_word, no_word, no_word, no_word, no_word, no_word, sentence

#   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
#   inputs2 = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs2 = tf.keras.preprocessing.sequence.pad_sequences([inputs2],
                                                         maxlen=max_length_inp,
                                                         padding='post')
#   inputs3 = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs3 = tf.keras.preprocessing.sequence.pad_sequences([inputs3],
                                                         maxlen=max_length_inp,
                                                         padding='post')
#   inputs4 = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs4 = tf.keras.preprocessing.sequence.pad_sequences([inputs4],
                                                         maxlen=max_length_inp,
                                                         padding='post')
#   inputs5 = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs5 = tf.keras.preprocessing.sequence.pad_sequences([inputs5],
                                                         maxlen=max_length_inp,
                                                         padding='post')
    
  inputs = tf.convert_to_tensor(inputs)
  inputs2 = tf.convert_to_tensor(inputs2)
  inputs3 = tf.convert_to_tensor(inputs3)
  inputs4 = tf.convert_to_tensor(inputs2)
  inputs5 = tf.convert_to_tensor(inputs3)


  result1 = ''
  result2 = ''
  result3 = ''
  result4 = ''
  result5 = ''
  voting_result = ''

  hidden = [tf.zeros((1, units))]
  hidden2 = [tf.zeros((1, units))]
  hidden3 = [tf.zeros((1, units))]
  hidden4 = [tf.zeros((1, units))]
  hidden5 = [tf.zeros((1, units))]

  # Encoder 의 hidden 을 Decoder 의 hidden 으로 받는다.
  enc_out, enc_hidden = models[0].encoder(inputs, hidden)

  enc_out2, enc_hidden2 = models[1].encoder(inputs2, hidden2)

  enc_out3, enc_hidden3 = models[2].encoder(inputs3, hidden3)

  enc_out4, enc_hidden4 = models[3].encoder(inputs4, hidden4)

  enc_out5, enc_hidden5 = models[4].encoder(inputs5, hidden5)



  dec_hidden = enc_hidden
  dec_hidden2 = enc_hidden2
  dec_hidden3 = enc_hidden3
  dec_hidden4 = enc_hidden4
  dec_hidden5 = enc_hidden5



  # Decoder 의 시작인 '<start>' 
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)
  dec_input2 = tf.expand_dims([targ_lang.word_index['<start>']], 0)
  dec_input3 = tf.expand_dims([targ_lang.word_index['<start>']], 0)
  dec_input4 = tf.expand_dims([targ_lang.word_index['<start>']], 0)
  dec_input5 = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  # Target 의 최대 길이 만큼 출력
  for t in range(max_length_inp):
    predictions, dec_hidden = models[0].decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)
    predictions2, dec_hidden2 = models[1].decoder(dec_input2,
                                                         dec_hidden2,
                                                         enc_out2)
    predictions3, dec_hidden3 = models[2].decoder(dec_input3,
                                                         dec_hidden3,
                                                         enc_out3)
    predictions4, dec_hidden4 = models[3].decoder(dec_input4,
                                                         dec_hidden4,
                                                         enc_out4)
    predictions5, dec_hidden5 = models[4].decoder(dec_input5,
                                                         dec_hidden5,
                                                         enc_out5)
    
    
    predicted_id = tf.argmax(predictions[0]).numpy() 
    predicted_id2 = tf.argmax(predictions2[0]).numpy() 
    predicted_id3 = tf.argmax(predictions3[0]).numpy() 
    predicted_id4 = tf.argmax(predictions4[0]).numpy() 
    predicted_id5 = tf.argmax(predictions5[0]).numpy()
    
    # Soft Voting
    predictions_sum = tf.add(predictions[0], predictions2[0], predictions3[0])
    predictions_sum = tf.add(predictions_sum, predictions4[0], predictions5[0])
    mean = tf.divide(predictions_sum, 5)
    voting_id = tf.argmax(mean).numpy()

    # tensorflow 에서 .numpy(): Tensor -> Numpy 로 바꿔주는 역할
    # predictions[0]  = tf.Tensor([-7.6920695 -7.9410057  3.7609155 ... ])

    print('p1 : ', predicted_id, mean[predicted_id])
    print('p2 : ', predicted_id2, mean[predicted_id2])
    print('p3 : ', predicted_id3, mean[predicted_id3])
    print('p4 : ', predicted_id4, mean[predicted_id4])
    print('p5 : ', predicted_id5, mean[predicted_id5])
    print('voting : ', voting_id, mean[voting_id])
    
    result1 += targ_lang.index_word[predicted_id] + ' '
    result2 += targ_lang.index_word[predicted_id2] + ' '
    result3 += targ_lang.index_word[predicted_id3] + ' '
    result4 += targ_lang.index_word[predicted_id4] + ' '
    result5 += targ_lang.index_word[predicted_id5] + ' '
    voting_result += targ_lang.index_word[voting_id] + ' '


    if targ_lang.index_word[voting_id] == '<end>':
      return result1, result2, result3, result4, result5, voting_result, sentence

    # 예측된 ID를 모델에 다시 피드합니다. (voting_id)
    dec_input = tf.expand_dims([voting_id], 0)
    dec_input2 = tf.expand_dims([voting_id], 0)
    dec_input3 = tf.expand_dims([voting_id], 0)
    dec_input4 = tf.expand_dims([voting_id], 0)
    dec_input5 = tf.expand_dims([voting_id], 0)

  return result1, result2, result3, result4, result5, voting_result, sentence

# %%
def translate(sentence, start_row):
    result1, result2, result3, result4, result5, voting_result, sentence = evaluate(sentence)
    result_list = [('Model 1', result1),
                   ('Model 2', result2),
                   ('Model 3', result3),
                   ('Model 4', result4),
                   ('Model 5', result5),
                   ('SoftVoting', voting_result)]
        
    # 엑셀 파일 불러오기
    wb = openpyxl.load_workbook('Accuracy_Compare.xlsx')

    # 엑셀 파일의 시트 활성화
    sheet = wb['SoftVoting(2)']

    
    for (model, item) in enumerate(result_list):
        if item[0] != 'SoftVoting':
            sheet.cell(row = start_row + model, column = 5).value = item[1]
        else :    
            sheet.cell(row = start_row + model, column = 6).value = item[1]
        
    
    wb.save('Accuracy_Compare.xlsx')

# %% [markdown]
# ### **Checkpoint 복원**

# %%
ckp_dir_m1 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb'
ckp_dir_m2 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 2'
ckp_dir_m3 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 3'
ckp_dir_m4 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 4'
ckp_dir_m5 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 5'

# %%
# checkpoint_dir내에 있는 최근 체크포인트(checkpoint)를 복원
checkpoints[0].restore(tf.train.latest_checkpoint(ckp_dir_m1))
checkpoints[1].restore(tf.train.latest_checkpoint(ckp_dir_m2))
checkpoints[2].restore(tf.train.latest_checkpoint(ckp_dir_m3))
checkpoints[3].restore(tf.train.latest_checkpoint(ckp_dir_m4))
checkpoints[4].restore(tf.train.latest_checkpoint(ckp_dir_m5))

### 이 코드로 했을 때 학습 바로 돌렸을 때와 같은 결과가 나왔음.

# %% [markdown]
# ### **번역 시작**

# %%
# test dataset 파일 불러오기
testdata = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/Test_Dataset/test_data.txt'
start_row = 2

f = open(testdata, 'r')
lines = f.readlines()

for sentence in lines:
    translate(sentence, start_row)
    start_row += 6
    
f.close()
# Out:
# sentence: <start> hace mucho frio aqui . <end>
# p1 :  14 tf.Tensor(7.0809298, shape=(), dtype=float32)
# p2 :  14 tf.Tensor(7.0809298, shape=(), dtype=float32)
# p3 :  14 tf.Tensor(7.0809298, shape=(), dtype=float32)
# p4 :  14 tf.Tensor(7.0809298, shape=(), dtype=float32)
# p5 :  14 tf.Tensor(7.0809298, shape=(), dtype=float32)
# voting :  14 tf.Tensor(7.0809298, shape=(), dtype=float32)
# p1 :  15 tf.Tensor(8.368726, shape=(), dtype=float32)
# p2 :  15 tf.Tensor(8.368726, shape=(), dtype=float32)
# p3 :  15 tf.Tensor(8.368726, shape=(), dtype=float32)
# p4 :  15 tf.Tensor(8.368726, shape=(), dtype=float32)
# p5 :  15 tf.Tensor(8.368726, shape=(), dtype=float32)
# voting :  15 tf.Tensor(8.368726, shape=(), dtype=float32)
# p1 :  89 tf.Tensor(6.233055, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(5.656337, shape=(), dtype=float32)
# p3 :  58 tf.Tensor(6.4271345, shape=(), dtype=float32)
# p4 :  89 tf.Tensor(6.233055, shape=(), dtype=float32)
# p5 :  58 tf.Tensor(6.4271345, shape=(), dtype=float32)
# voting :  58 tf.Tensor(6.4271345, shape=(), dtype=float32)
# p1 :  282 tf.Tensor(9.930204, shape=(), dtype=float32)
# p2 :  282 tf.Tensor(9.930204, shape=(), dtype=float32)
# p3 :  282 tf.Tensor(9.930204, shape=(), dtype=float32)
# p4 :  282 tf.Tensor(9.930204, shape=(), dtype=float32)
# p5 :  282 tf.Tensor(9.930204, shape=(), dtype=float32)
# voting :  282 tf.Tensor(9.930204, shape=(), dtype=float32)
# p1 :  62 tf.Tensor(7.8132615, shape=(), dtype=float32)
# p2 :  62 tf.Tensor(7.8132615, shape=(), dtype=float32)
# p3 :  62 tf.Tensor(7.8132615, shape=(), dtype=float32)
# p4 :  62 tf.Tensor(7.8132615, shape=(), dtype=float32)
# p5 :  62 tf.Tensor(7.8132615, shape=(), dtype=float32)
# voting :  62 tf.Tensor(7.8132615, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(8.540173, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(8.540173, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(8.540173, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(8.540173, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(8.540173, shape=(), dtype=float32)
# voting :  3 tf.Tensor(8.540173, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.950633, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.950633, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.950633, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.950633, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.950633, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.950633, shape=(), dtype=float32)
# sentence: <start> esta es mi vida . <end>
# p1 :  21 tf.Tensor(8.977327, shape=(), dtype=float32)
# p2 :  21 tf.Tensor(8.977327, shape=(), dtype=float32)
# p3 :  21 tf.Tensor(8.977327, shape=(), dtype=float32)
# p4 :  21 tf.Tensor(8.977327, shape=(), dtype=float32)
# p5 :  21 tf.Tensor(8.977327, shape=(), dtype=float32)
# voting :  21 tf.Tensor(8.977327, shape=(), dtype=float32)
# p1 :  11 tf.Tensor(9.042831, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(9.042831, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(9.042831, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(9.042831, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(9.042831, shape=(), dtype=float32)
# voting :  11 tf.Tensor(9.042831, shape=(), dtype=float32)
# p1 :  25 tf.Tensor(11.565448, shape=(), dtype=float32)
# p2 :  25 tf.Tensor(11.565448, shape=(), dtype=float32)
# p3 :  25 tf.Tensor(11.565448, shape=(), dtype=float32)
# p4 :  25 tf.Tensor(11.565448, shape=(), dtype=float32)
# p5 :  25 tf.Tensor(11.565448, shape=(), dtype=float32)
# voting :  25 tf.Tensor(11.565448, shape=(), dtype=float32)
# p1 :  192 tf.Tensor(7.964099, shape=(), dtype=float32)
# p2 :  192 tf.Tensor(7.964099, shape=(), dtype=float32)
# p3 :  192 tf.Tensor(7.964099, shape=(), dtype=float32)
# p4 :  192 tf.Tensor(7.964099, shape=(), dtype=float32)
# p5 :  192 tf.Tensor(7.964099, shape=(), dtype=float32)
# voting :  192 tf.Tensor(7.964099, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.252669, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.252669, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.252669, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.252669, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.252669, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.252669, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.312442, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.312442, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.312442, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.312442, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.312442, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.312442, shape=(), dtype=float32)
# sentence: <start> ¿ todavia estan en casa ? <end>
# p1 :  32 tf.Tensor(8.324343, shape=(), dtype=float32)
# p2 :  32 tf.Tensor(8.324343, shape=(), dtype=float32)
# p3 :  32 tf.Tensor(8.324343, shape=(), dtype=float32)
# p4 :  32 tf.Tensor(8.324343, shape=(), dtype=float32)
# p5 :  32 tf.Tensor(8.324343, shape=(), dtype=float32)
# voting :  32 tf.Tensor(8.324343, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(8.279083, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(8.279083, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(8.279083, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(8.279083, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(8.279083, shape=(), dtype=float32)
# voting :  7 tf.Tensor(8.279083, shape=(), dtype=float32)
# p1 :  156 tf.Tensor(8.852226, shape=(), dtype=float32)
# p2 :  156 tf.Tensor(8.852226, shape=(), dtype=float32)
# p3 :  156 tf.Tensor(8.852226, shape=(), dtype=float32)
# p4 :  156 tf.Tensor(8.852226, shape=(), dtype=float32)
# p5 :  156 tf.Tensor(8.852226, shape=(), dtype=float32)
# voting :  156 tf.Tensor(8.852226, shape=(), dtype=float32)
# p1 :  44 tf.Tensor(8.810827, shape=(), dtype=float32)
# p2 :  44 tf.Tensor(8.810827, shape=(), dtype=float32)
# p3 :  44 tf.Tensor(8.810827, shape=(), dtype=float32)
# p4 :  44 tf.Tensor(8.810827, shape=(), dtype=float32)
# p5 :  44 tf.Tensor(8.810827, shape=(), dtype=float32)
# voting :  44 tf.Tensor(8.810827, shape=(), dtype=float32)
# p1 :  112 tf.Tensor(9.26388, shape=(), dtype=float32)
# p2 :  112 tf.Tensor(9.26388, shape=(), dtype=float32)
# p3 :  112 tf.Tensor(9.26388, shape=(), dtype=float32)
# p4 :  112 tf.Tensor(9.26388, shape=(), dtype=float32)
# p5 :  112 tf.Tensor(9.26388, shape=(), dtype=float32)
# voting :  112 tf.Tensor(9.26388, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(9.675109, shape=(), dtype=float32)
# p2 :  10 tf.Tensor(9.675109, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(9.675109, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(9.675109, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(9.675109, shape=(), dtype=float32)
# voting :  10 tf.Tensor(9.675109, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.146997, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.146997, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.146997, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.146997, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.146997, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.146997, shape=(), dtype=float32)
# sentence: <start> trata de averiguarlo . <end>
# p1 :  264 tf.Tensor(7.4425783, shape=(), dtype=float32)
# p2 :  264 tf.Tensor(7.4425783, shape=(), dtype=float32)
# p3 :  264 tf.Tensor(7.4425783, shape=(), dtype=float32)
# p4 :  264 tf.Tensor(7.4425783, shape=(), dtype=float32)
# p5 :  264 tf.Tensor(7.4425783, shape=(), dtype=float32)
# voting :  264 tf.Tensor(7.4425783, shape=(), dtype=float32)
# p1 :  6 tf.Tensor(7.343737, shape=(), dtype=float32)
# p2 :  6 tf.Tensor(7.343737, shape=(), dtype=float32)
# p3 :  6 tf.Tensor(7.343737, shape=(), dtype=float32)
# p4 :  6 tf.Tensor(7.343737, shape=(), dtype=float32)
# p5 :  6 tf.Tensor(7.343737, shape=(), dtype=float32)
# voting :  6 tf.Tensor(7.343737, shape=(), dtype=float32)
# p1 :  205 tf.Tensor(4.317132, shape=(), dtype=float32)
# p2 :  893 tf.Tensor(8.753554, shape=(), dtype=float32)
# p3 :  893 tf.Tensor(8.753554, shape=(), dtype=float32)
# p4 :  893 tf.Tensor(8.753554, shape=(), dtype=float32)
# p5 :  893 tf.Tensor(8.753554, shape=(), dtype=float32)
# voting :  893 tf.Tensor(8.753554, shape=(), dtype=float32)
# p1 :  14 tf.Tensor(9.329176, shape=(), dtype=float32)
# p2 :  14 tf.Tensor(9.329176, shape=(), dtype=float32)
# p3 :  14 tf.Tensor(9.329176, shape=(), dtype=float32)
# p4 :  67 tf.Tensor(8.521388, shape=(), dtype=float32)
# p5 :  14 tf.Tensor(9.329176, shape=(), dtype=float32)
# voting :  14 tf.Tensor(9.329176, shape=(), dtype=float32)
# p1 :  67 tf.Tensor(6.3311987, shape=(), dtype=float32)
# p2 :  67 tf.Tensor(6.3311987, shape=(), dtype=float32)
# p3 :  67 tf.Tensor(6.3311987, shape=(), dtype=float32)
# p4 :  67 tf.Tensor(6.3311987, shape=(), dtype=float32)
# p5 :  67 tf.Tensor(6.3311987, shape=(), dtype=float32)
# voting :  67 tf.Tensor(6.3311987, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(7.2064056, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(7.2064056, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(7.2064056, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(7.2064056, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(7.2064056, shape=(), dtype=float32)
# voting :  3 tf.Tensor(7.2064056, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.641177, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.641177, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.641177, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.641177, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.641177, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.641177, shape=(), dtype=float32)
# sentence: <start> te quiero <end>
# p1 :  4 tf.Tensor(9.020082, shape=(), dtype=float32)
# p2 :  4 tf.Tensor(9.020082, shape=(), dtype=float32)
# p3 :  4 tf.Tensor(9.020082, shape=(), dtype=float32)
# p4 :  4 tf.Tensor(9.020082, shape=(), dtype=float32)
# p5 :  4 tf.Tensor(9.020082, shape=(), dtype=float32)
# voting :  4 tf.Tensor(9.020082, shape=(), dtype=float32)
# p1 :  155 tf.Tensor(8.645081, shape=(), dtype=float32)
# p2 :  155 tf.Tensor(8.645081, shape=(), dtype=float32)
# p3 :  155 tf.Tensor(8.645081, shape=(), dtype=float32)
# p4 :  155 tf.Tensor(8.645081, shape=(), dtype=float32)
# p5 :  155 tf.Tensor(8.645081, shape=(), dtype=float32)
# voting :  155 tf.Tensor(8.645081, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(9.740862, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(9.740862, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(9.740862, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(9.740862, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(9.740862, shape=(), dtype=float32)
# voting :  7 tf.Tensor(9.740862, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(5.289102, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(5.289102, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(5.289102, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(5.289102, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(5.289102, shape=(), dtype=float32)
# voting :  3 tf.Tensor(5.289102, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(10.662697, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(10.662697, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(10.662697, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(10.662697, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(10.662697, shape=(), dtype=float32)
# voting :  2 tf.Tensor(10.662697, shape=(), dtype=float32)
# sentence: <start> le pregunto que estaba pasando , pero ella no dijo nada . <end>
# p1 :  28 tf.Tensor(7.519236, shape=(), dtype=float32)
# p2 :  28 tf.Tensor(7.519236, shape=(), dtype=float32)
# p3 :  4 tf.Tensor(6.196443, shape=(), dtype=float32)
# p4 :  28 tf.Tensor(7.519236, shape=(), dtype=float32)
# p5 :  28 tf.Tensor(7.519236, shape=(), dtype=float32)
# voting :  28 tf.Tensor(7.519236, shape=(), dtype=float32)
# p1 :  169 tf.Tensor(10.343094, shape=(), dtype=float32)
# p2 :  169 tf.Tensor(10.343094, shape=(), dtype=float32)
# p3 :  169 tf.Tensor(10.343094, shape=(), dtype=float32)
# p4 :  169 tf.Tensor(10.343094, shape=(), dtype=float32)
# p5 :  169 tf.Tensor(10.343094, shape=(), dtype=float32)
# voting :  169 tf.Tensor(10.343094, shape=(), dtype=float32)
# p1 :  46 tf.Tensor(9.616655, shape=(), dtype=float32)
# p2 :  46 tf.Tensor(9.616655, shape=(), dtype=float32)
# p3 :  46 tf.Tensor(9.616655, shape=(), dtype=float32)
# p4 :  46 tf.Tensor(9.616655, shape=(), dtype=float32)
# p5 :  46 tf.Tensor(9.616655, shape=(), dtype=float32)
# voting :  46 tf.Tensor(9.616655, shape=(), dtype=float32)
# p1 :  29 tf.Tensor(7.3054595, shape=(), dtype=float32)
# p2 :  29 tf.Tensor(7.3054595, shape=(), dtype=float32)
# p3 :  29 tf.Tensor(7.3054595, shape=(), dtype=float32)
# p4 :  29 tf.Tensor(7.3054595, shape=(), dtype=float32)
# p5 :  13 tf.Tensor(6.012166, shape=(), dtype=float32)
# voting :  29 tf.Tensor(7.3054595, shape=(), dtype=float32)
# p1 :  13 tf.Tensor(6.114634, shape=(), dtype=float32)
# p2 :  19 tf.Tensor(6.451024, shape=(), dtype=float32)
# p3 :  13 tf.Tensor(6.114634, shape=(), dtype=float32)
# p4 :  19 tf.Tensor(6.451024, shape=(), dtype=float32)
# p5 :  13 tf.Tensor(6.114634, shape=(), dtype=float32)
# voting :  19 tf.Tensor(6.451024, shape=(), dtype=float32)
# p1 :  78 tf.Tensor(5.401311, shape=(), dtype=float32)
# p2 :  949 tf.Tensor(4.5980325, shape=(), dtype=float32)
# p3 :  78 tf.Tensor(5.401311, shape=(), dtype=float32)
# p4 :  78 tf.Tensor(5.401311, shape=(), dtype=float32)
# p5 :  78 tf.Tensor(5.401311, shape=(), dtype=float32)
# voting :  78 tf.Tensor(5.401311, shape=(), dtype=float32)
# p1 :  6 tf.Tensor(6.3641787, shape=(), dtype=float32)
# p2 :  36 tf.Tensor(6.483873, shape=(), dtype=float32)
# p3 :  67 tf.Tensor(3.3127015, shape=(), dtype=float32)
# p4 :  20 tf.Tensor(6.586852, shape=(), dtype=float32)
# p5 :  36 tf.Tensor(6.483873, shape=(), dtype=float32)
# voting :  20 tf.Tensor(6.586852, shape=(), dtype=float32)
# p1 :  94 tf.Tensor(7.273791, shape=(), dtype=float32)
# p2 :  94 tf.Tensor(7.273791, shape=(), dtype=float32)
# p3 :  94 tf.Tensor(7.273791, shape=(), dtype=float32)
# p4 :  94 tf.Tensor(7.273791, shape=(), dtype=float32)
# p5 :  13 tf.Tensor(3.8476098, shape=(), dtype=float32)
# voting :  94 tf.Tensor(7.273791, shape=(), dtype=float32)
# p1 :  28 tf.Tensor(7.697812, shape=(), dtype=float32)
# p2 :  28 tf.Tensor(7.697812, shape=(), dtype=float32)
# p3 :  28 tf.Tensor(7.697812, shape=(), dtype=float32)
# p4 :  28 tf.Tensor(7.697812, shape=(), dtype=float32)
# p5 :  28 tf.Tensor(7.697812, shape=(), dtype=float32)
# voting :  28 tf.Tensor(7.697812, shape=(), dtype=float32)
# p1 :  64 tf.Tensor(8.7839985, shape=(), dtype=float32)
# p2 :  64 tf.Tensor(8.7839985, shape=(), dtype=float32)
# p3 :  64 tf.Tensor(8.7839985, shape=(), dtype=float32)
# p4 :  64 tf.Tensor(8.7839985, shape=(), dtype=float32)
# p5 :  64 tf.Tensor(8.7839985, shape=(), dtype=float32)
# voting :  64 tf.Tensor(8.7839985, shape=(), dtype=float32)
# p1 :  12 tf.Tensor(11.784413, shape=(), dtype=float32)
# p2 :  12 tf.Tensor(11.784413, shape=(), dtype=float32)
# p3 :  12 tf.Tensor(11.784413, shape=(), dtype=float32)
# p4 :  12 tf.Tensor(11.784413, shape=(), dtype=float32)
# p5 :  12 tf.Tensor(11.784413, shape=(), dtype=float32)
# voting :  12 tf.Tensor(11.784413, shape=(), dtype=float32)
# p1 :  45 tf.Tensor(3.6242166, shape=(), dtype=float32)
# p2 :  147 tf.Tensor(5.632161, shape=(), dtype=float32)
# p3 :  147 tf.Tensor(5.632161, shape=(), dtype=float32)
# p4 :  147 tf.Tensor(5.632161, shape=(), dtype=float32)
# p5 :  147 tf.Tensor(5.632161, shape=(), dtype=float32)
# voting :  147 tf.Tensor(5.632161, shape=(), dtype=float32)
# p1 :  182 tf.Tensor(5.7600403, shape=(), dtype=float32)
# p2 :  127 tf.Tensor(6.3195305, shape=(), dtype=float32)
# p3 :  127 tf.Tensor(6.3195305, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(4.9095163, shape=(), dtype=float32)
# p5 :  182 tf.Tensor(5.7600403, shape=(), dtype=float32)
# voting :  127 tf.Tensor(6.3195305, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(8.673166, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(8.673166, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(8.673166, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(8.673166, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(8.673166, shape=(), dtype=float32)
# voting :  3 tf.Tensor(8.673166, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.0453005, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.0453005, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.0453005, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.0453005, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.0453005, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.0453005, shape=(), dtype=float32)
# sentence: <start> lo elegimos capitan de nuestro equipo . <end>
# p1 :  27 tf.Tensor(9.978945, shape=(), dtype=float32)
# p2 :  27 tf.Tensor(9.978945, shape=(), dtype=float32)
# p3 :  27 tf.Tensor(9.978945, shape=(), dtype=float32)
# p4 :  27 tf.Tensor(9.978945, shape=(), dtype=float32)
# p5 :  27 tf.Tensor(9.978945, shape=(), dtype=float32)
# voting :  27 tf.Tensor(9.978945, shape=(), dtype=float32)
# p1 :  1775 tf.Tensor(9.021022, shape=(), dtype=float32)
# p2 :  1775 tf.Tensor(9.021022, shape=(), dtype=float32)
# p3 :  1775 tf.Tensor(9.021022, shape=(), dtype=float32)
# p4 :  1775 tf.Tensor(9.021022, shape=(), dtype=float32)
# p5 :  1775 tf.Tensor(9.021022, shape=(), dtype=float32)
# voting :  1775 tf.Tensor(9.021022, shape=(), dtype=float32)
# p1 :  46 tf.Tensor(7.982957, shape=(), dtype=float32)
# p2 :  46 tf.Tensor(7.982957, shape=(), dtype=float32)
# p3 :  46 tf.Tensor(7.982957, shape=(), dtype=float32)
# p4 :  46 tf.Tensor(7.982957, shape=(), dtype=float32)
# p5 :  46 tf.Tensor(7.982957, shape=(), dtype=float32)
# voting :  46 tf.Tensor(7.982957, shape=(), dtype=float32)
# p1 :  125 tf.Tensor(4.614405, shape=(), dtype=float32)
# p2 :  1790 tf.Tensor(5.3108306, shape=(), dtype=float32)
# p3 :  125 tf.Tensor(4.614405, shape=(), dtype=float32)
# p4 :  18 tf.Tensor(5.505599, shape=(), dtype=float32)
# p5 :  125 tf.Tensor(4.614405, shape=(), dtype=float32)
# voting :  18 tf.Tensor(5.505599, shape=(), dtype=float32)
# p1 :  125 tf.Tensor(9.620508, shape=(), dtype=float32)
# p2 :  125 tf.Tensor(9.620508, shape=(), dtype=float32)
# p3 :  125 tf.Tensor(9.620508, shape=(), dtype=float32)
# p4 :  125 tf.Tensor(9.620508, shape=(), dtype=float32)
# p5 :  125 tf.Tensor(9.620508, shape=(), dtype=float32)
# voting :  125 tf.Tensor(9.620508, shape=(), dtype=float32)
# p1 :  685 tf.Tensor(8.638837, shape=(), dtype=float32)
# p2 :  685 tf.Tensor(8.638837, shape=(), dtype=float32)
# p3 :  685 tf.Tensor(8.638837, shape=(), dtype=float32)
# p4 :  685 tf.Tensor(8.638837, shape=(), dtype=float32)
# p5 :  685 tf.Tensor(8.638837, shape=(), dtype=float32)
# voting :  685 tf.Tensor(8.638837, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(8.145944, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(8.145944, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(8.145944, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(8.145944, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(8.145944, shape=(), dtype=float32)
# voting :  3 tf.Tensor(8.145944, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.722887, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.722887, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.722887, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.722887, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.722887, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.722887, shape=(), dtype=float32)
# sentence: <start> lo vi en las noticias . <end>
# p1 :  4 tf.Tensor(8.511064, shape=(), dtype=float32)
# p2 :  4 tf.Tensor(8.511064, shape=(), dtype=float32)
# p3 :  4 tf.Tensor(8.511064, shape=(), dtype=float32)
# p4 :  4 tf.Tensor(8.511064, shape=(), dtype=float32)
# p5 :  4 tf.Tensor(8.511064, shape=(), dtype=float32)
# voting :  4 tf.Tensor(8.511064, shape=(), dtype=float32)
# p1 :  173 tf.Tensor(8.77854, shape=(), dtype=float32)
# p2 :  173 tf.Tensor(8.77854, shape=(), dtype=float32)
# p3 :  173 tf.Tensor(8.77854, shape=(), dtype=float32)
# p4 :  173 tf.Tensor(8.77854, shape=(), dtype=float32)
# p5 :  173 tf.Tensor(8.77854, shape=(), dtype=float32)
# voting :  173 tf.Tensor(8.77854, shape=(), dtype=float32)
# p1 :  46 tf.Tensor(7.9559965, shape=(), dtype=float32)
# p2 :  14 tf.Tensor(7.5462923, shape=(), dtype=float32)
# p3 :  46 tf.Tensor(7.9559965, shape=(), dtype=float32)
# p4 :  46 tf.Tensor(7.9559965, shape=(), dtype=float32)
# p5 :  46 tf.Tensor(7.9559965, shape=(), dtype=float32)
# voting :  46 tf.Tensor(7.9559965, shape=(), dtype=float32)
# p1 :  16 tf.Tensor(7.0651827, shape=(), dtype=float32)
# p2 :  16 tf.Tensor(7.0651827, shape=(), dtype=float32)
# p3 :  16 tf.Tensor(7.0651827, shape=(), dtype=float32)
# p4 :  16 tf.Tensor(7.0651827, shape=(), dtype=float32)
# p5 :  44 tf.Tensor(6.5824966, shape=(), dtype=float32)
# voting :  16 tf.Tensor(7.0651827, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(6.935332, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(6.935332, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(6.935332, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(6.935332, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(6.935332, shape=(), dtype=float32)
# voting :  5 tf.Tensor(6.935332, shape=(), dtype=float32)
# p1 :  580 tf.Tensor(7.693579, shape=(), dtype=float32)
# p2 :  580 tf.Tensor(7.693579, shape=(), dtype=float32)
# p3 :  580 tf.Tensor(7.693579, shape=(), dtype=float32)
# p4 :  580 tf.Tensor(7.693579, shape=(), dtype=float32)
# p5 :  580 tf.Tensor(7.693579, shape=(), dtype=float32)
# voting :  580 tf.Tensor(7.693579, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.056116, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.056116, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.056116, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.056116, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.056116, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.056116, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.698832, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.698832, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.698832, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.698832, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.698832, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.698832, shape=(), dtype=float32)
# sentence: <start> el paso por mi casa anoche . <end>
# p1 :  13 tf.Tensor(7.7075667, shape=(), dtype=float32)
# p2 :  13 tf.Tensor(7.7075667, shape=(), dtype=float32)
# p3 :  13 tf.Tensor(7.7075667, shape=(), dtype=float32)
# p4 :  13 tf.Tensor(7.7075667, shape=(), dtype=float32)
# p5 :  13 tf.Tensor(7.7075667, shape=(), dtype=float32)
# voting :  13 tf.Tensor(7.7075667, shape=(), dtype=float32)
# p1 :  118 tf.Tensor(6.130423, shape=(), dtype=float32)
# p2 :  512 tf.Tensor(6.8730073, shape=(), dtype=float32)
# p3 :  512 tf.Tensor(6.8730073, shape=(), dtype=float32)
# p4 :  512 tf.Tensor(6.8730073, shape=(), dtype=float32)
# p5 :  512 tf.Tensor(6.8730073, shape=(), dtype=float32)
# voting :  512 tf.Tensor(6.8730073, shape=(), dtype=float32)
# p1 :  25 tf.Tensor(5.822526, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(5.680243, shape=(), dtype=float32)
# p3 :  25 tf.Tensor(5.822526, shape=(), dtype=float32)
# p4 :  25 tf.Tensor(5.822526, shape=(), dtype=float32)
# p5 :  25 tf.Tensor(5.822526, shape=(), dtype=float32)
# voting :  25 tf.Tensor(5.822526, shape=(), dtype=float32)
# p1 :  121 tf.Tensor(7.8358564, shape=(), dtype=float32)
# p2 :  121 tf.Tensor(7.8358564, shape=(), dtype=float32)
# p3 :  121 tf.Tensor(7.8358564, shape=(), dtype=float32)
# p4 :  121 tf.Tensor(7.8358564, shape=(), dtype=float32)
# p5 :  121 tf.Tensor(7.8358564, shape=(), dtype=float32)
# voting :  121 tf.Tensor(7.8358564, shape=(), dtype=float32)
# p1 :  113 tf.Tensor(7.0550385, shape=(), dtype=float32)
# p2 :  113 tf.Tensor(7.0550385, shape=(), dtype=float32)
# p3 :  113 tf.Tensor(7.0550385, shape=(), dtype=float32)
# p4 :  171 tf.Tensor(4.8191032, shape=(), dtype=float32)
# p5 :  113 tf.Tensor(7.0550385, shape=(), dtype=float32)
# voting :  113 tf.Tensor(7.0550385, shape=(), dtype=float32)
# p1 :  160 tf.Tensor(10.684351, shape=(), dtype=float32)
# p2 :  160 tf.Tensor(10.684351, shape=(), dtype=float32)
# p3 :  160 tf.Tensor(10.684351, shape=(), dtype=float32)
# p4 :  160 tf.Tensor(10.684351, shape=(), dtype=float32)
# p5 :  160 tf.Tensor(10.684351, shape=(), dtype=float32)
# voting :  160 tf.Tensor(10.684351, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.754171, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.754171, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.754171, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.754171, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.754171, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.754171, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.077711, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.077711, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.077711, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.077711, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.077711, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.077711, shape=(), dtype=float32)
# sentence: <start> habia dos asientos desocupados . <end>
# p1 :  47 tf.Tensor(6.5788827, shape=(), dtype=float32)
# p2 :  47 tf.Tensor(6.5788827, shape=(), dtype=float32)
# p3 :  148 tf.Tensor(4.083934, shape=(), dtype=float32)
# p4 :  47 tf.Tensor(6.5788827, shape=(), dtype=float32)
# p5 :  47 tf.Tensor(6.5788827, shape=(), dtype=float32)
# voting :  47 tf.Tensor(6.5788827, shape=(), dtype=float32)
# p1 :  19 tf.Tensor(7.0838137, shape=(), dtype=float32)
# p2 :  77 tf.Tensor(8.657994, shape=(), dtype=float32)
# p3 :  77 tf.Tensor(8.657994, shape=(), dtype=float32)
# p4 :  77 tf.Tensor(8.657994, shape=(), dtype=float32)
# p5 :  77 tf.Tensor(8.657994, shape=(), dtype=float32)
# voting :  77 tf.Tensor(8.657994, shape=(), dtype=float32)
# p1 :  148 tf.Tensor(7.721245, shape=(), dtype=float32)
# p2 :  148 tf.Tensor(7.721245, shape=(), dtype=float32)
# p3 :  148 tf.Tensor(7.721245, shape=(), dtype=float32)
# p4 :  148 tf.Tensor(7.721245, shape=(), dtype=float32)
# p5 :  148 tf.Tensor(7.721245, shape=(), dtype=float32)
# voting :  148 tf.Tensor(7.721245, shape=(), dtype=float32)
# p1 :  3758 tf.Tensor(4.422788, shape=(), dtype=float32)
# p2 :  4175 tf.Tensor(2.932384, shape=(), dtype=float32)
# p3 :  1353 tf.Tensor(2.7309902, shape=(), dtype=float32)
# p4 :  2204 tf.Tensor(5.492746, shape=(), dtype=float32)
# p5 :  3220 tf.Tensor(0.49446535, shape=(), dtype=float32)
# voting :  2204 tf.Tensor(5.492746, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(6.5942445, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(6.5942445, shape=(), dtype=float32)
# p3 :  1334 tf.Tensor(2.802712, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(6.5942445, shape=(), dtype=float32)
# p5 :  1334 tf.Tensor(2.802712, shape=(), dtype=float32)
# voting :  3 tf.Tensor(6.5942445, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.878894, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.878894, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.878894, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.878894, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.878894, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.878894, shape=(), dtype=float32)
# sentence: <start> debes ocuparte del nino . <end>
# p1 :  7 tf.Tensor(9.652053, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(9.652053, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(9.652053, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(9.652053, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(9.652053, shape=(), dtype=float32)
# voting :  7 tf.Tensor(9.652053, shape=(), dtype=float32)
# p1 :  128 tf.Tensor(7.48969, shape=(), dtype=float32)
# p2 :  128 tf.Tensor(7.48969, shape=(), dtype=float32)
# p3 :  69 tf.Tensor(6.397295, shape=(), dtype=float32)
# p4 :  128 tf.Tensor(7.48969, shape=(), dtype=float32)
# p5 :  128 tf.Tensor(7.48969, shape=(), dtype=float32)
# voting :  128 tf.Tensor(7.48969, shape=(), dtype=float32)
# p1 :  514 tf.Tensor(4.6233606, shape=(), dtype=float32)
# p2 :  164 tf.Tensor(4.7254686, shape=(), dtype=float32)
# p3 :  107 tf.Tensor(5.535201, shape=(), dtype=float32)
# p4 :  305 tf.Tensor(4.481881, shape=(), dtype=float32)
# p5 :  164 tf.Tensor(4.7254686, shape=(), dtype=float32)
# voting :  68 tf.Tensor(5.84188, shape=(), dtype=float32)
# p1 :  159 tf.Tensor(5.3457804, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(3.1796029, shape=(), dtype=float32)
# p3 :  76 tf.Tensor(2.3185184, shape=(), dtype=float32)
# p4 :  159 tf.Tensor(5.3457804, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(5.1104283, shape=(), dtype=float32)
# voting :  159 tf.Tensor(5.3457804, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(7.634122, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(7.634122, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(7.634122, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(7.634122, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(7.634122, shape=(), dtype=float32)
# voting :  5 tf.Tensor(7.634122, shape=(), dtype=float32)
# p1 :  372 tf.Tensor(6.70055, shape=(), dtype=float32)
# p2 :  372 tf.Tensor(6.70055, shape=(), dtype=float32)
# p3 :  372 tf.Tensor(6.70055, shape=(), dtype=float32)
# p4 :  372 tf.Tensor(6.70055, shape=(), dtype=float32)
# p5 :  372 tf.Tensor(6.70055, shape=(), dtype=float32)
# voting :  372 tf.Tensor(6.70055, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(8.097583, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(8.097583, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(8.097583, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(8.097583, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(8.097583, shape=(), dtype=float32)
# voting :  3 tf.Tensor(8.097583, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.851497, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.851497, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.851497, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.851497, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.851497, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.851497, shape=(), dtype=float32)
# sentence: <start> la calle ha sido cerrada . <end>
# p1 :  5 tf.Tensor(8.776413, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(8.776413, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(8.776413, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(8.776413, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(8.776413, shape=(), dtype=float32)
# voting :  5 tf.Tensor(8.776413, shape=(), dtype=float32)
# p1 :  631 tf.Tensor(7.2577972, shape=(), dtype=float32)
# p2 :  631 tf.Tensor(7.2577972, shape=(), dtype=float32)
# p3 :  631 tf.Tensor(7.2577972, shape=(), dtype=float32)
# p4 :  631 tf.Tensor(7.2577972, shape=(), dtype=float32)
# p5 :  631 tf.Tensor(7.2577972, shape=(), dtype=float32)
# voting :  631 tf.Tensor(7.2577972, shape=(), dtype=float32)
# p1 :  59 tf.Tensor(4.819719, shape=(), dtype=float32)
# p2 :  51 tf.Tensor(6.3590784, shape=(), dtype=float32)
# p3 :  51 tf.Tensor(6.3590784, shape=(), dtype=float32)
# p4 :  15 tf.Tensor(4.5140076, shape=(), dtype=float32)
# p5 :  51 tf.Tensor(6.3590784, shape=(), dtype=float32)
# voting :  51 tf.Tensor(6.3590784, shape=(), dtype=float32)
# p1 :  450 tf.Tensor(5.332239, shape=(), dtype=float32)
# p2 :  89 tf.Tensor(6.6360674, shape=(), dtype=float32)
# p3 :  89 tf.Tensor(6.6360674, shape=(), dtype=float32)
# p4 :  89 tf.Tensor(6.6360674, shape=(), dtype=float32)
# p5 :  89 tf.Tensor(6.6360674, shape=(), dtype=float32)
# voting :  89 tf.Tensor(6.6360674, shape=(), dtype=float32)
# p1 :  741 tf.Tensor(5.0873747, shape=(), dtype=float32)
# p2 :  752 tf.Tensor(8.083526, shape=(), dtype=float32)
# p3 :  752 tf.Tensor(8.083526, shape=(), dtype=float32)
# p4 :  752 tf.Tensor(8.083526, shape=(), dtype=float32)
# p5 :  1113 tf.Tensor(6.1281905, shape=(), dtype=float32)
# voting :  752 tf.Tensor(8.083526, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(10.003049, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(10.003049, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(10.003049, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(10.003049, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(10.003049, shape=(), dtype=float32)
# voting :  3 tf.Tensor(10.003049, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.987524, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.987524, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.987524, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.987524, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.987524, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.987524, shape=(), dtype=float32)
# sentence: <start> tom queria saber si mary tenia novio . <end>
# p1 :  8 tf.Tensor(9.755926, shape=(), dtype=float32)
# p2 :  8 tf.Tensor(9.755926, shape=(), dtype=float32)
# p3 :  8 tf.Tensor(9.755926, shape=(), dtype=float32)
# p4 :  8 tf.Tensor(9.755926, shape=(), dtype=float32)
# p5 :  8 tf.Tensor(9.755926, shape=(), dtype=float32)
# voting :  8 tf.Tensor(9.755926, shape=(), dtype=float32)
# p1 :  161 tf.Tensor(11.141902, shape=(), dtype=float32)
# p2 :  161 tf.Tensor(11.141902, shape=(), dtype=float32)
# p3 :  161 tf.Tensor(11.141902, shape=(), dtype=float32)
# p4 :  161 tf.Tensor(11.141902, shape=(), dtype=float32)
# p5 :  161 tf.Tensor(11.141902, shape=(), dtype=float32)
# voting :  161 tf.Tensor(11.141902, shape=(), dtype=float32)
# p1 :  6 tf.Tensor(10.43479, shape=(), dtype=float32)
# p2 :  6 tf.Tensor(10.43479, shape=(), dtype=float32)
# p3 :  6 tf.Tensor(10.43479, shape=(), dtype=float32)
# p4 :  6 tf.Tensor(10.43479, shape=(), dtype=float32)
# p5 :  6 tf.Tensor(10.43479, shape=(), dtype=float32)
# voting :  6 tf.Tensor(10.43479, shape=(), dtype=float32)
# p1 :  45 tf.Tensor(9.62087, shape=(), dtype=float32)
# p2 :  45 tf.Tensor(9.62087, shape=(), dtype=float32)
# p3 :  45 tf.Tensor(9.62087, shape=(), dtype=float32)
# p4 :  45 tf.Tensor(9.62087, shape=(), dtype=float32)
# p5 :  45 tf.Tensor(9.62087, shape=(), dtype=float32)
# voting :  45 tf.Tensor(9.62087, shape=(), dtype=float32)
# p1 :  71 tf.Tensor(9.593836, shape=(), dtype=float32)
# p2 :  71 tf.Tensor(9.593836, shape=(), dtype=float32)
# p3 :  71 tf.Tensor(9.593836, shape=(), dtype=float32)
# p4 :  71 tf.Tensor(9.593836, shape=(), dtype=float32)
# p5 :  71 tf.Tensor(9.593836, shape=(), dtype=float32)
# voting :  71 tf.Tensor(9.593836, shape=(), dtype=float32)
# p1 :  31 tf.Tensor(10.69474, shape=(), dtype=float32)
# p2 :  31 tf.Tensor(10.69474, shape=(), dtype=float32)
# p3 :  31 tf.Tensor(10.69474, shape=(), dtype=float32)
# p4 :  31 tf.Tensor(10.69474, shape=(), dtype=float32)
# p5 :  31 tf.Tensor(10.69474, shape=(), dtype=float32)
# voting :  31 tf.Tensor(10.69474, shape=(), dtype=float32)
# p1 :  19 tf.Tensor(7.1405244, shape=(), dtype=float32)
# p2 :  59 tf.Tensor(7.2446504, shape=(), dtype=float32)
# p3 :  59 tf.Tensor(7.2446504, shape=(), dtype=float32)
# p4 :  19 tf.Tensor(7.1405244, shape=(), dtype=float32)
# p5 :  59 tf.Tensor(7.2446504, shape=(), dtype=float32)
# voting :  59 tf.Tensor(7.2446504, shape=(), dtype=float32)
# p1 :  9 tf.Tensor(6.887651, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(6.887651, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(6.887651, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(6.887651, shape=(), dtype=float32)
# p5 :  9 tf.Tensor(6.887651, shape=(), dtype=float32)
# voting :  9 tf.Tensor(6.887651, shape=(), dtype=float32)
# p1 :  838 tf.Tensor(6.6279144, shape=(), dtype=float32)
# p2 :  838 tf.Tensor(6.6279144, shape=(), dtype=float32)
# p3 :  838 tf.Tensor(6.6279144, shape=(), dtype=float32)
# p4 :  838 tf.Tensor(6.6279144, shape=(), dtype=float32)
# p5 :  838 tf.Tensor(6.6279144, shape=(), dtype=float32)
# voting :  838 tf.Tensor(6.6279144, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(8.531174, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(8.531174, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(8.531174, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(8.531174, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(8.531174, shape=(), dtype=float32)
# voting :  3 tf.Tensor(8.531174, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(13.006772, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(13.006772, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(13.006772, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(13.006772, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(13.006772, shape=(), dtype=float32)
# voting :  2 tf.Tensor(13.006772, shape=(), dtype=float32)
# sentence: <start> es la educacion la llave al exito . <end>
# p1 :  5 tf.Tensor(4.6830196, shape=(), dtype=float32)
# p2 :  21 tf.Tensor(4.6209183, shape=(), dtype=float32)
# p3 :  14 tf.Tensor(6.1101446, shape=(), dtype=float32)
# p4 :  14 tf.Tensor(6.1101446, shape=(), dtype=float32)
# p5 :  14 tf.Tensor(6.1101446, shape=(), dtype=float32)
# voting :  14 tf.Tensor(6.1101446, shape=(), dtype=float32)
# p1 :  15 tf.Tensor(9.591822, shape=(), dtype=float32)
# p2 :  15 tf.Tensor(9.591822, shape=(), dtype=float32)
# p3 :  15 tf.Tensor(9.591822, shape=(), dtype=float32)
# p4 :  15 tf.Tensor(9.591822, shape=(), dtype=float32)
# p5 :  15 tf.Tensor(9.591822, shape=(), dtype=float32)
# voting :  15 tf.Tensor(9.591822, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(5.696508, shape=(), dtype=float32)
# p2 :  1822 tf.Tensor(7.829187, shape=(), dtype=float32)
# p3 :  1822 tf.Tensor(7.829187, shape=(), dtype=float32)
# p4 :  1822 tf.Tensor(7.829187, shape=(), dtype=float32)
# p5 :  1822 tf.Tensor(7.829187, shape=(), dtype=float32)
# voting :  1822 tf.Tensor(7.829187, shape=(), dtype=float32)
# p1 :  20 tf.Tensor(4.1505136, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(4.914061, shape=(), dtype=float32)
# p3 :  17 tf.Tensor(5.723857, shape=(), dtype=float32)
# p4 :  17 tf.Tensor(5.723857, shape=(), dtype=float32)
# p5 :  17 tf.Tensor(5.723857, shape=(), dtype=float32)
# voting :  17 tf.Tensor(5.723857, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(3.5606563, shape=(), dtype=float32)
# p2 :  623 tf.Tensor(3.8838334, shape=(), dtype=float32)
# p3 :  623 tf.Tensor(3.8838334, shape=(), dtype=float32)
# p4 :  623 tf.Tensor(3.8838334, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(2.7585983, shape=(), dtype=float32)
# voting :  623 tf.Tensor(3.8838334, shape=(), dtype=float32)
# p1 :  6 tf.Tensor(7.7008514, shape=(), dtype=float32)
# p2 :  6 tf.Tensor(7.7008514, shape=(), dtype=float32)
# p3 :  6 tf.Tensor(7.7008514, shape=(), dtype=float32)
# p4 :  6 tf.Tensor(7.7008514, shape=(), dtype=float32)
# p5 :  6 tf.Tensor(7.7008514, shape=(), dtype=float32)
# voting :  6 tf.Tensor(7.7008514, shape=(), dtype=float32)
# p1 :  824 tf.Tensor(5.283206, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(5.8517323, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(5.8517323, shape=(), dtype=float32)
# p4 :  34 tf.Tensor(4.6675673, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(5.8517323, shape=(), dtype=float32)
# voting :  5 tf.Tensor(5.8517323, shape=(), dtype=float32)
# p1 :  824 tf.Tensor(7.576979, shape=(), dtype=float32)
# p2 :  824 tf.Tensor(7.576979, shape=(), dtype=float32)
# p3 :  824 tf.Tensor(7.576979, shape=(), dtype=float32)
# p4 :  824 tf.Tensor(7.576979, shape=(), dtype=float32)
# p5 :  824 tf.Tensor(7.576979, shape=(), dtype=float32)
# voting :  824 tf.Tensor(7.576979, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(9.926712, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(9.926712, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(9.926712, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(9.926712, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(9.926712, shape=(), dtype=float32)
# voting :  3 tf.Tensor(9.926712, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.090326, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.090326, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.090326, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.090326, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.090326, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.090326, shape=(), dtype=float32)
# sentence: <start> pon un poco mas de pimienta . <end>
# p1 :  178 tf.Tensor(6.1146955, shape=(), dtype=float32)
# p2 :  178 tf.Tensor(6.1146955, shape=(), dtype=float32)
# p3 :  178 tf.Tensor(6.1146955, shape=(), dtype=float32)
# p4 :  178 tf.Tensor(6.1146955, shape=(), dtype=float32)
# p5 :  178 tf.Tensor(6.1146955, shape=(), dtype=float32)
# voting :  178 tf.Tensor(6.1146955, shape=(), dtype=float32)
# p1 :  106 tf.Tensor(7.9108047, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(7.3076677, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(7.3076677, shape=(), dtype=float32)
# p4 :  106 tf.Tensor(7.9108047, shape=(), dtype=float32)
# p5 :  106 tf.Tensor(7.9108047, shape=(), dtype=float32)
# voting :  106 tf.Tensor(7.9108047, shape=(), dtype=float32)
# p1 :  93 tf.Tensor(5.0730996, shape=(), dtype=float32)
# p2 :  93 tf.Tensor(5.0730996, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(3.279345, shape=(), dtype=float32)
# p4 :  93 tf.Tensor(5.0730996, shape=(), dtype=float32)
# p5 :  93 tf.Tensor(5.0730996, shape=(), dtype=float32)
# voting :  93 tf.Tensor(5.0730996, shape=(), dtype=float32)
# p1 :  1321 tf.Tensor(1.8497137, shape=(), dtype=float32)
# p2 :  1835 tf.Tensor(3.4158654, shape=(), dtype=float32)
# p3 :  620 tf.Tensor(0.70564383, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(3.426265, shape=(), dtype=float32)
# p5 :  95 tf.Tensor(3.5429702, shape=(), dtype=float32)
# voting :  93 tf.Tensor(3.8328369, shape=(), dtype=float32)
# p1 :  269 tf.Tensor(3.334303, shape=(), dtype=float32)
# p2 :  2548 tf.Tensor(6.1538115, shape=(), dtype=float32)
# p3 :  620 tf.Tensor(0.38105136, shape=(), dtype=float32)
# p4 :  2548 tf.Tensor(6.1538115, shape=(), dtype=float32)
# p5 :  2548 tf.Tensor(6.1538115, shape=(), dtype=float32)
# voting :  2548 tf.Tensor(6.1538115, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(10.007299, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(10.007299, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(10.007299, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(10.007299, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(10.007299, shape=(), dtype=float32)
# voting :  3 tf.Tensor(10.007299, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.105413, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.105413, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.105413, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.105413, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.105413, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.105413, shape=(), dtype=float32)
# sentence: <start> la inclinacion del terreno hacia dificil la construccion de la carretera . <end>
# p1 :  13 tf.Tensor(5.010865, shape=(), dtype=float32)
# p2 :  13 tf.Tensor(5.010865, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(4.718744, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(4.718744, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(4.718744, shape=(), dtype=float32)
# voting :  13 tf.Tensor(5.010865, shape=(), dtype=float32)
# p1 :  2092 tf.Tensor(4.2230406, shape=(), dtype=float32)
# p2 :  19 tf.Tensor(4.394932, shape=(), dtype=float32)
# p3 :  2302 tf.Tensor(1.6720035, shape=(), dtype=float32)
# p4 :  3344 tf.Tensor(4.78478, shape=(), dtype=float32)
# p5 :  19 tf.Tensor(4.394932, shape=(), dtype=float32)
# voting :  3344 tf.Tensor(4.78478, shape=(), dtype=float32)
# p1 :  50 tf.Tensor(6.3549423, shape=(), dtype=float32)
# p2 :  50 tf.Tensor(6.3549423, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(6.169661, shape=(), dtype=float32)
# p4 :  18 tf.Tensor(2.0164018, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(6.169661, shape=(), dtype=float32)
# voting :  50 tf.Tensor(6.3549423, shape=(), dtype=float32)
# p1 :  848 tf.Tensor(1.0562984, shape=(), dtype=float32)
# p2 :  376 tf.Tensor(0.90353745, shape=(), dtype=float32)
# p3 :  18 tf.Tensor(2.5819302, shape=(), dtype=float32)
# p4 :  882 tf.Tensor(0.40912, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(2.9071689, shape=(), dtype=float32)
# voting :  5 tf.Tensor(2.9071689, shape=(), dtype=float32)
# p1 :  4283 tf.Tensor(3.2346992, shape=(), dtype=float32)
# p2 :  257 tf.Tensor(3.347531, shape=(), dtype=float32)
# p3 :  258 tf.Tensor(2.5240552, shape=(), dtype=float32)
# p4 :  1112 tf.Tensor(1.8747492, shape=(), dtype=float32)
# p5 :  354 tf.Tensor(3.0342267, shape=(), dtype=float32)
# voting :  257 tf.Tensor(3.347531, shape=(), dtype=float32)
# p1 :  6 tf.Tensor(3.8652077, shape=(), dtype=float32)
# p2 :  6 tf.Tensor(3.8652077, shape=(), dtype=float32)
# p3 :  18 tf.Tensor(4.2273493, shape=(), dtype=float32)
# p4 :  18 tf.Tensor(4.2273493, shape=(), dtype=float32)
# p5 :  18 tf.Tensor(4.2273493, shape=(), dtype=float32)
# voting :  18 tf.Tensor(4.2273493, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(6.9022574, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(6.9022574, shape=(), dtype=float32)
# p3 :  258 tf.Tensor(3.4601645, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(6.9022574, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(6.9022574, shape=(), dtype=float32)
# voting :  5 tf.Tensor(6.9022574, shape=(), dtype=float32)
# p1 :  658 tf.Tensor(3.0685294, shape=(), dtype=float32)
# p2 :  1948 tf.Tensor(4.1214204, shape=(), dtype=float32)
# p3 :  258 tf.Tensor(1.1991, shape=(), dtype=float32)
# p4 :  1948 tf.Tensor(4.1214204, shape=(), dtype=float32)
# p5 :  760 tf.Tensor(2.1117246, shape=(), dtype=float32)
# voting :  1948 tf.Tensor(4.1214204, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(4.4556355, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(4.4556355, shape=(), dtype=float32)
# p3 :  15 tf.Tensor(3.5969474, shape=(), dtype=float32)
# p4 :  1112 tf.Tensor(0.23499489, shape=(), dtype=float32)
# p5 :  18 tf.Tensor(2.7050185, shape=(), dtype=float32)
# voting :  3 tf.Tensor(4.4556355, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(10.325511, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(10.325511, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(10.325511, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(10.325511, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(10.325511, shape=(), dtype=float32)
# voting :  2 tf.Tensor(10.325511, shape=(), dtype=float32)
# sentence: <start> el precio de las lecciones de piano incluye el uso del piano . <end>
# p1 :  5 tf.Tensor(8.686414, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(8.686414, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(8.686414, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(8.686414, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(8.686414, shape=(), dtype=float32)
# voting :  5 tf.Tensor(8.686414, shape=(), dtype=float32)
# p1 :  900 tf.Tensor(8.148309, shape=(), dtype=float32)
# p2 :  900 tf.Tensor(8.148309, shape=(), dtype=float32)
# p3 :  900 tf.Tensor(8.148309, shape=(), dtype=float32)
# p4 :  900 tf.Tensor(8.148309, shape=(), dtype=float32)
# p5 :  900 tf.Tensor(8.148309, shape=(), dtype=float32)
# voting :  900 tf.Tensor(8.148309, shape=(), dtype=float32)
# p1 :  18 tf.Tensor(8.389902, shape=(), dtype=float32)
# p2 :  18 tf.Tensor(8.389902, shape=(), dtype=float32)
# p3 :  18 tf.Tensor(8.389902, shape=(), dtype=float32)
# p4 :  18 tf.Tensor(8.389902, shape=(), dtype=float32)
# p5 :  18 tf.Tensor(8.389902, shape=(), dtype=float32)
# voting :  18 tf.Tensor(8.389902, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(6.830716, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(6.830716, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(6.830716, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(6.830716, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(6.830716, shape=(), dtype=float32)
# voting :  5 tf.Tensor(6.830716, shape=(), dtype=float32)
# p1 :  876 tf.Tensor(0.49147433, shape=(), dtype=float32)
# p2 :  8865 tf.Tensor(0.37109423, shape=(), dtype=float32)
# p3 :  1112 tf.Tensor(0.8540158, shape=(), dtype=float32)
# p4 :  2769 tf.Tensor(3.4425197, shape=(), dtype=float32)
# p5 :  711 tf.Tensor(2.8324637, shape=(), dtype=float32)
# voting :  2769 tf.Tensor(3.4425197, shape=(), dtype=float32)
# p1 :  18 tf.Tensor(4.583293, shape=(), dtype=float32)
# p2 :  15 tf.Tensor(3.8822842, shape=(), dtype=float32)
# p3 :  15 tf.Tensor(3.8822842, shape=(), dtype=float32)
# p4 :  32 tf.Tensor(3.3315501, shape=(), dtype=float32)
# p5 :  18 tf.Tensor(4.583293, shape=(), dtype=float32)
# voting :  18 tf.Tensor(4.583293, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(6.86217, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(6.86217, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(6.86217, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(6.86217, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(6.86217, shape=(), dtype=float32)
# voting :  5 tf.Tensor(6.86217, shape=(), dtype=float32)
# p1 :  876 tf.Tensor(1.5050403, shape=(), dtype=float32)
# p2 :  4855 tf.Tensor(3.6825345, shape=(), dtype=float32)
# p3 :  671 tf.Tensor(-1.1668105, shape=(), dtype=float32)
# p4 :  3050 tf.Tensor(2.3277333, shape=(), dtype=float32)
# p5 :  711 tf.Tensor(4.3379908, shape=(), dtype=float32)
# voting :  711 tf.Tensor(4.3379908, shape=(), dtype=float32)
# p1 :  6158 tf.Tensor(0.89412516, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(2.6398423, shape=(), dtype=float32)
# p3 :  1612 tf.Tensor(1.6380064, shape=(), dtype=float32)
# p4 :  478 tf.Tensor(3.1144552, shape=(), dtype=float32)
# p5 :  15 tf.Tensor(3.2873282, shape=(), dtype=float32)
# voting :  15 tf.Tensor(3.2873282, shape=(), dtype=float32)
# p1 :  3482 tf.Tensor(1.9881121, shape=(), dtype=float32)
# p2 :  711 tf.Tensor(3.55903, shape=(), dtype=float32)
# p3 :  861 tf.Tensor(0.56011486, shape=(), dtype=float32)
# p4 :  1187 tf.Tensor(2.08272, shape=(), dtype=float32)
# p5 :  1454 tf.Tensor(0.9195255, shape=(), dtype=float32)
# voting :  711 tf.Tensor(3.55903, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(6.528566, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(6.528566, shape=(), dtype=float32)
# p3 :  44 tf.Tensor(1.8474407, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(6.528566, shape=(), dtype=float32)
# p5 :  15 tf.Tensor(2.0061696, shape=(), dtype=float32)
# voting :  3 tf.Tensor(6.528566, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.533716, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.533716, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.533716, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.533716, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.533716, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.533716, shape=(), dtype=float32)
# sentence: <start> nuestra lengua materna es el japones . <end>
# ...
# p4 :  2 tf.Tensor(12.678347, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.678347, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.678347, shape=(), dtype=float32)
# sentence: <start> tom es una persona muy gentil . <end>
# p1 :  8 tf.Tensor(9.869674, shape=(), dtype=float32)
# p2 :  8 tf.Tensor(9.869674, shape=(), dtype=float32)
# p3 :  8 tf.Tensor(9.869674, shape=(), dtype=float32)
# p4 :  8 tf.Tensor(9.869674, shape=(), dtype=float32)
# p5 :  8 tf.Tensor(9.869674, shape=(), dtype=float32)
# voting :  8 tf.Tensor(9.869674, shape=(), dtype=float32)
# p1 :  11 tf.Tensor(9.8284, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(9.8284, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(9.8284, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(9.8284, shape=(), dtype=float32)
# p5 :  11 tf.Tensor(9.8284, shape=(), dtype=float32)
# voting :  11 tf.Tensor(9.8284, shape=(), dtype=float32)
# p1 :  9 tf.Tensor(9.249315, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(9.249315, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(9.249315, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(9.249315, shape=(), dtype=float32)
# p5 :  9 tf.Tensor(9.249315, shape=(), dtype=float32)
# voting :  9 tf.Tensor(9.249315, shape=(), dtype=float32)
# p1 :  58 tf.Tensor(7.9512687, shape=(), dtype=float32)
# p2 :  58 tf.Tensor(7.9512687, shape=(), dtype=float32)
# p3 :  58 tf.Tensor(7.9512687, shape=(), dtype=float32)
# p4 :  58 tf.Tensor(7.9512687, shape=(), dtype=float32)
# p5 :  58 tf.Tensor(7.9512687, shape=(), dtype=float32)
# voting :  58 tf.Tensor(7.9512687, shape=(), dtype=float32)
# p1 :  441 tf.Tensor(5.9521837, shape=(), dtype=float32)
# p2 :  322 tf.Tensor(6.2909937, shape=(), dtype=float32)
# p3 :  8466 tf.Tensor(-0.78084517, shape=(), dtype=float32)
# p4 :  441 tf.Tensor(5.9521837, shape=(), dtype=float32)
# p5 :  322 tf.Tensor(6.2909937, shape=(), dtype=float32)
# voting :  322 tf.Tensor(6.2909937, shape=(), dtype=float32)
# p1 :  273 tf.Tensor(8.166306, shape=(), dtype=float32)
# p2 :  18 tf.Tensor(6.6881323, shape=(), dtype=float32)
# p3 :  273 tf.Tensor(8.166306, shape=(), dtype=float32)
# p4 :  273 tf.Tensor(8.166306, shape=(), dtype=float32)
# p5 :  273 tf.Tensor(8.166306, shape=(), dtype=float32)
# voting :  273 tf.Tensor(8.166306, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(8.474007, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(8.474007, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(8.474007, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(8.474007, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(8.474007, shape=(), dtype=float32)
# voting :  3 tf.Tensor(8.474007, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(12.178296, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(12.178296, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(12.178296, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(12.178296, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(12.178296, shape=(), dtype=float32)
# voting :  2 tf.Tensor(12.178296, shape=(), dtype=float32)
# sentence: <start> el es un tipo extrano . <end>
# p1 :  13 tf.Tensor(9.749646, shape=(), dtype=float32)
# p2 :  13 tf.Tensor(9.749646, shape=(), dtype=float32)
# p3 :  13 tf.Tensor(9.749646, shape=(), dtype=float32)
# p4 :  13 tf.Tensor(9.749646, shape=(), dtype=float32)
# p5 :  13 tf.Tensor(9.749646, shape=(), dtype=float32)
# voting :  13 tf.Tensor(9.749646, shape=(), dtype=float32)
# p1 :  11 tf.Tensor(8.705421, shape=(), dtype=float32)
# p2 :  11 tf.Tensor(8.705421, shape=(), dtype=float32)
# p3 :  11 tf.Tensor(8.705421, shape=(), dtype=float32)
# p4 :  11 tf.Tensor(8.705421, shape=(), dtype=float32)
# p5 :  15 tf.Tensor(8.39702, shape=(), dtype=float32)
# voting :  11 tf.Tensor(8.705421, shape=(), dtype=float32)
# p1 :  9 tf.Tensor(9.85052, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(9.85052, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(9.85052, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(9.85052, shape=(), dtype=float32)
# p5 :  9 tf.Tensor(9.85052, shape=(), dtype=float32)
# voting :  9 tf.Tensor(9.85052, shape=(), dtype=float32)
# p1 :  1787 tf.Tensor(7.2994585, shape=(), dtype=float32)
# p2 :  1787 tf.Tensor(7.2994585, shape=(), dtype=float32)
# p3 :  1787 tf.Tensor(7.2994585, shape=(), dtype=float32)
# p4 :  1787 tf.Tensor(7.2994585, shape=(), dtype=float32)
# p5 :  1787 tf.Tensor(7.2994585, shape=(), dtype=float32)
# voting :  1787 tf.Tensor(7.2994585, shape=(), dtype=float32)
# p1 :  693 tf.Tensor(9.60078, shape=(), dtype=float32)
# p2 :  693 tf.Tensor(9.60078, shape=(), dtype=float32)
# p3 :  693 tf.Tensor(9.60078, shape=(), dtype=float32)
# p4 :  693 tf.Tensor(9.60078, shape=(), dtype=float32)
# p5 :  693 tf.Tensor(9.60078, shape=(), dtype=float32)
# voting :  693 tf.Tensor(9.60078, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(10.286211, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(10.286211, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(10.286211, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(10.286211, shape=(), dtype=float32)
# p5 :  3 tf.Tensor(10.286211, shape=(), dtype=float32)
# voting :  3 tf.Tensor(10.286211, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.536172, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.536172, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.536172, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.536172, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.536172, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.536172, shape=(), dtype=float32)
# sentence: <start> pense que tom y maria eran gemelos . <end>
# p1 :  4 tf.Tensor(7.7227716, shape=(), dtype=float32)
# p2 :  4 tf.Tensor(7.7227716, shape=(), dtype=float32)
# p3 :  4 tf.Tensor(7.7227716, shape=(), dtype=float32)
# p4 :  4 tf.Tensor(7.7227716, shape=(), dtype=float32)
# p5 :  4 tf.Tensor(7.7227716, shape=(), dtype=float32)
# voting :  4 tf.Tensor(7.7227716, shape=(), dtype=float32)
# p1 :  145 tf.Tensor(10.88819, shape=(), dtype=float32)
# p2 :  145 tf.Tensor(10.88819, shape=(), dtype=float32)
# p3 :  145 tf.Tensor(10.88819, shape=(), dtype=float32)
# p4 :  145 tf.Tensor(10.88819, shape=(), dtype=float32)
# p5 :  145 tf.Tensor(10.88819, shape=(), dtype=float32)
# voting :  145 tf.Tensor(10.88819, shape=(), dtype=float32)
# p1 :  8 tf.Tensor(9.471094, shape=(), dtype=float32)
# p2 :  8 tf.Tensor(9.471094, shape=(), dtype=float32)
# p3 :  8 tf.Tensor(9.471094, shape=(), dtype=float32)
# p4 :  8 tf.Tensor(9.471094, shape=(), dtype=float32)
# p5 :  8 tf.Tensor(9.471094, shape=(), dtype=float32)
# voting :  8 tf.Tensor(9.471094, shape=(), dtype=float32)
# p1 :  42 tf.Tensor(8.614845, shape=(), dtype=float32)
# p2 :  42 tf.Tensor(8.614845, shape=(), dtype=float32)
# p3 :  42 tf.Tensor(8.614845, shape=(), dtype=float32)
# p4 :  42 tf.Tensor(8.614845, shape=(), dtype=float32)
# p5 :  42 tf.Tensor(8.614845, shape=(), dtype=float32)
# voting :  42 tf.Tensor(8.614845, shape=(), dtype=float32)
# p1 :  31 tf.Tensor(9.572119, shape=(), dtype=float32)
# p2 :  31 tf.Tensor(9.572119, shape=(), dtype=float32)
# p3 :  31 tf.Tensor(9.572119, shape=(), dtype=float32)
# p4 :  31 tf.Tensor(9.572119, shape=(), dtype=float32)
# p5 :  31 tf.Tensor(9.572119, shape=(), dtype=float32)
# voting :  31 tf.Tensor(9.572119, shape=(), dtype=float32)
# p1 :  77 tf.Tensor(10.221904, shape=(), dtype=float32)
# p2 :  77 tf.Tensor(10.221904, shape=(), dtype=float32)
# p3 :  77 tf.Tensor(10.221904, shape=(), dtype=float32)
# p4 :  77 tf.Tensor(10.221904, shape=(), dtype=float32)
# p5 :  77 tf.Tensor(10.221904, shape=(), dtype=float32)
# voting :  77 tf.Tensor(10.221904, shape=(), dtype=float32)
# p1 :  314 tf.Tensor(4.642022, shape=(), dtype=float32)
# p2 :  1185 tf.Tensor(2.5102952, shape=(), dtype=float32)
# p3 :  156 tf.Tensor(0.29300803, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(4.130774, shape=(), dtype=float32)
# p5 :  2499 tf.Tensor(3.4377398, shape=(), dtype=float32)
# voting :  314 tf.Tensor(4.642022, shape=(), dtype=float32)
# p1 :  3 tf.Tensor(5.5200853, shape=(), dtype=float32)
# p2 :  3 tf.Tensor(5.5200853, shape=(), dtype=float32)
# p3 :  3 tf.Tensor(5.5200853, shape=(), dtype=float32)
# p4 :  3 tf.Tensor(5.5200853, shape=(), dtype=float32)
# p5 :  31 tf.Tensor(-1.3289416, shape=(), dtype=float32)
# voting :  3 tf.Tensor(5.5200853, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(13.03647, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(13.03647, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(13.03647, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(13.03647, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(13.03647, shape=(), dtype=float32)
# voting :  2 tf.Tensor(13.03647, shape=(), dtype=float32)
# sentence: <start> ¿ cuando fue la ultima vez que te quedaste en un hotel ? <end>
# p1 :  72 tf.Tensor(10.343552, shape=(), dtype=float32)
# p2 :  72 tf.Tensor(10.343552, shape=(), dtype=float32)
# p3 :  72 tf.Tensor(10.343552, shape=(), dtype=float32)
# p4 :  72 tf.Tensor(10.343552, shape=(), dtype=float32)
# p5 :  72 tf.Tensor(10.343552, shape=(), dtype=float32)
# voting :  72 tf.Tensor(10.343552, shape=(), dtype=float32)
# p1 :  19 tf.Tensor(8.298928, shape=(), dtype=float32)
# p2 :  19 tf.Tensor(8.298928, shape=(), dtype=float32)
# p3 :  19 tf.Tensor(8.298928, shape=(), dtype=float32)
# p4 :  19 tf.Tensor(8.298928, shape=(), dtype=float32)
# p5 :  19 tf.Tensor(8.298928, shape=(), dtype=float32)
# voting :  19 tf.Tensor(8.298928, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(9.973912, shape=(), dtype=float32)
# p2 :  5 tf.Tensor(9.973912, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(9.973912, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(9.973912, shape=(), dtype=float32)
# p5 :  5 tf.Tensor(9.973912, shape=(), dtype=float32)
# voting :  5 tf.Tensor(9.973912, shape=(), dtype=float32)
# p1 :  113 tf.Tensor(9.51425, shape=(), dtype=float32)
# p2 :  113 tf.Tensor(9.51425, shape=(), dtype=float32)
# p3 :  113 tf.Tensor(9.51425, shape=(), dtype=float32)
# p4 :  113 tf.Tensor(9.51425, shape=(), dtype=float32)
# p5 :  113 tf.Tensor(9.51425, shape=(), dtype=float32)
# voting :  113 tf.Tensor(9.51425, shape=(), dtype=float32)
# p1 :  56 tf.Tensor(9.821669, shape=(), dtype=float32)
# p2 :  56 tf.Tensor(9.821669, shape=(), dtype=float32)
# p3 :  56 tf.Tensor(9.821669, shape=(), dtype=float32)
# p4 :  56 tf.Tensor(9.821669, shape=(), dtype=float32)
# p5 :  56 tf.Tensor(9.821669, shape=(), dtype=float32)
# voting :  56 tf.Tensor(9.821669, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(9.479632, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(9.479632, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(9.479632, shape=(), dtype=float32)
# p4 :  7 tf.Tensor(9.479632, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(9.479632, shape=(), dtype=float32)
# voting :  7 tf.Tensor(9.479632, shape=(), dtype=float32)
# p1 :  118 tf.Tensor(4.640948, shape=(), dtype=float32)
# p2 :  100 tf.Tensor(5.7752814, shape=(), dtype=float32)
# p3 :  193 tf.Tensor(4.695025, shape=(), dtype=float32)
# p4 :  216 tf.Tensor(6.47081, shape=(), dtype=float32)
# p5 :  59 tf.Tensor(5.535077, shape=(), dtype=float32)
# voting :  216 tf.Tensor(6.47081, shape=(), dtype=float32)
# p1 :  36 tf.Tensor(4.952317, shape=(), dtype=float32)
# p2 :  1025 tf.Tensor(4.0752954, shape=(), dtype=float32)
# p3 :  183 tf.Tensor(3.644509, shape=(), dtype=float32)
# p4 :  44 tf.Tensor(2.6808436, shape=(), dtype=float32)
# p5 :  7 tf.Tensor(4.562847, shape=(), dtype=float32)
# voting :  9 tf.Tensor(5.3183084, shape=(), dtype=float32)
# p1 :  559 tf.Tensor(7.1638594, shape=(), dtype=float32)
# p2 :  559 tf.Tensor(7.1638594, shape=(), dtype=float32)
# p3 :  559 tf.Tensor(7.1638594, shape=(), dtype=float32)
# p4 :  559 tf.Tensor(7.1638594, shape=(), dtype=float32)
# p5 :  559 tf.Tensor(7.1638594, shape=(), dtype=float32)
# voting :  559 tf.Tensor(7.1638594, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(8.235988, shape=(), dtype=float32)
# p2 :  10 tf.Tensor(8.235988, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(8.235988, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(8.235988, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(8.235988, shape=(), dtype=float32)
# voting :  10 tf.Tensor(8.235988, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.627771, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.627771, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.627771, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.627771, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.627771, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.627771, shape=(), dtype=float32)
# sentence: <start> ¿ cuantos anos tenia la primera vez que condujo un coche ? <end>
# p1 :  54 tf.Tensor(9.382257, shape=(), dtype=float32)
# p2 :  54 tf.Tensor(9.382257, shape=(), dtype=float32)
# p3 :  54 tf.Tensor(9.382257, shape=(), dtype=float32)
# p4 :  54 tf.Tensor(9.382257, shape=(), dtype=float32)
# p5 :  54 tf.Tensor(9.382257, shape=(), dtype=float32)
# voting :  54 tf.Tensor(9.382257, shape=(), dtype=float32)
# p1 :  152 tf.Tensor(8.062426, shape=(), dtype=float32)
# p2 :  152 tf.Tensor(8.062426, shape=(), dtype=float32)
# p3 :  152 tf.Tensor(8.062426, shape=(), dtype=float32)
# p4 :  152 tf.Tensor(8.062426, shape=(), dtype=float32)
# p5 :  152 tf.Tensor(8.062426, shape=(), dtype=float32)
# voting :  152 tf.Tensor(8.062426, shape=(), dtype=float32)
# p1 :  55 tf.Tensor(5.1781554, shape=(), dtype=float32)
# p2 :  19 tf.Tensor(5.6045523, shape=(), dtype=float32)
# p3 :  19 tf.Tensor(5.6045523, shape=(), dtype=float32)
# p4 :  19 tf.Tensor(5.6045523, shape=(), dtype=float32)
# p5 :  19 tf.Tensor(5.6045523, shape=(), dtype=float32)
# voting :  19 tf.Tensor(5.6045523, shape=(), dtype=float32)
# p1 :  5 tf.Tensor(6.503724, shape=(), dtype=float32)
# p2 :  28 tf.Tensor(5.614291, shape=(), dtype=float32)
# p3 :  5 tf.Tensor(6.503724, shape=(), dtype=float32)
# p4 :  5 tf.Tensor(6.503724, shape=(), dtype=float32)
# p5 :  4 tf.Tensor(5.240155, shape=(), dtype=float32)
# voting :  5 tf.Tensor(6.503724, shape=(), dtype=float32)
# p1 :  194 tf.Tensor(6.846956, shape=(), dtype=float32)
# p2 :  194 tf.Tensor(6.846956, shape=(), dtype=float32)
# p3 :  194 tf.Tensor(6.846956, shape=(), dtype=float32)
# p4 :  194 tf.Tensor(6.846956, shape=(), dtype=float32)
# p5 :  194 tf.Tensor(6.846956, shape=(), dtype=float32)
# voting :  194 tf.Tensor(6.846956, shape=(), dtype=float32)
# p1 :  56 tf.Tensor(7.3713264, shape=(), dtype=float32)
# p2 :  56 tf.Tensor(7.3713264, shape=(), dtype=float32)
# p3 :  56 tf.Tensor(7.3713264, shape=(), dtype=float32)
# p4 :  56 tf.Tensor(7.3713264, shape=(), dtype=float32)
# p5 :  56 tf.Tensor(7.3713264, shape=(), dtype=float32)
# voting :  56 tf.Tensor(7.3713264, shape=(), dtype=float32)
# p1 :  7 tf.Tensor(6.4052415, shape=(), dtype=float32)
# p2 :  7 tf.Tensor(6.4052415, shape=(), dtype=float32)
# p3 :  7 tf.Tensor(6.4052415, shape=(), dtype=float32)
# p4 :  27 tf.Tensor(4.390571, shape=(), dtype=float32)
# p5 :  6 tf.Tensor(3.0045772, shape=(), dtype=float32)
# voting :  7 tf.Tensor(6.4052415, shape=(), dtype=float32)
# p1 :  1327 tf.Tensor(1.0565487, shape=(), dtype=float32)
# p2 :  656 tf.Tensor(4.0878606, shape=(), dtype=float32)
# p3 :  1573 tf.Tensor(2.0672164, shape=(), dtype=float32)
# p4 :  1244 tf.Tensor(1.7662754, shape=(), dtype=float32)
# p5 :  296 tf.Tensor(2.749515, shape=(), dtype=float32)
# voting :  656 tf.Tensor(4.0878606, shape=(), dtype=float32)
# p1 :  6 tf.Tensor(5.9559937, shape=(), dtype=float32)
# p2 :  9 tf.Tensor(7.589328, shape=(), dtype=float32)
# p3 :  9 tf.Tensor(7.589328, shape=(), dtype=float32)
# p4 :  9 tf.Tensor(7.589328, shape=(), dtype=float32)
# p5 :  6 tf.Tensor(5.9559937, shape=(), dtype=float32)
# voting :  9 tf.Tensor(7.589328, shape=(), dtype=float32)
# p1 :  110 tf.Tensor(8.437097, shape=(), dtype=float32)
# p2 :  110 tf.Tensor(8.437097, shape=(), dtype=float32)
# p3 :  110 tf.Tensor(8.437097, shape=(), dtype=float32)
# p4 :  110 tf.Tensor(8.437097, shape=(), dtype=float32)
# p5 :  110 tf.Tensor(8.437097, shape=(), dtype=float32)
# voting :  110 tf.Tensor(8.437097, shape=(), dtype=float32)
# p1 :  10 tf.Tensor(8.033465, shape=(), dtype=float32)
# p2 :  10 tf.Tensor(8.033465, shape=(), dtype=float32)
# p3 :  10 tf.Tensor(8.033465, shape=(), dtype=float32)
# p4 :  10 tf.Tensor(8.033465, shape=(), dtype=float32)
# p5 :  10 tf.Tensor(8.033465, shape=(), dtype=float32)
# voting :  10 tf.Tensor(8.033465, shape=(), dtype=float32)
# p1 :  2 tf.Tensor(11.671351, shape=(), dtype=float32)
# p2 :  2 tf.Tensor(11.671351, shape=(), dtype=float32)
# p3 :  2 tf.Tensor(11.671351, shape=(), dtype=float32)
# p4 :  2 tf.Tensor(11.671351, shape=(), dtype=float32)
# p5 :  2 tf.Tensor(11.671351, shape=(), dtype=float32)
# voting :  2 tf.Tensor(11.671351, shape=(), dtype=float32)

# %% [markdown]
# ### 긴 문장 번역 Test ###
#
# Le preguntó qué estaba pasando, pero ella no dijo nada.
#
# He asked her what was going on, but she didn't say anything.

# %%
# long_test = u'Le preguntó qué estaba pasando, pero ella no dijo nada.'
# translate(long_test)

# %% [markdown]
# ### 더 긴 문장 번역 Test ###
#
# Si quieres sonar como un hablante nativo, debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un músico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado.
#
# If you want to sound like a native speaker, you must be willing toq practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo.

# %%
# long_test2 = u'Si quieres sonar como un hablante nativo, debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un músico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado.'

# translate(long_test)
